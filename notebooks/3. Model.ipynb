# %% [markdown]
# # Смена директории

# %%
# %cd ..
# Out:
# /Users/uzumnasiya/HSE/Year_Project

# %% [markdown]
# # Импорт библиотек

# %%
import logging
import warnings


import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import yaml
import joblib
import shap
import optuna
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from category_encoders import CatBoostEncoder
from catboost import CatBoostClassifier


from utils.dev_utils import get_pool
from utils.pipeline_utils import CustomPreprocessor
from utils.metrics import MetricCalculator, metric_funcs
from utils.style.styler import style_metrics
from utils.style.html_output import print_multiple_html
from utils.plot_utils import plot_gini_by_period_styled, plot_roc_by_masks

# %%
logging.getLogger().setLevel(logging.WARNING)
warnings.filterwarnings('ignore')
sns.set_palette('bright')


pd.options.display.float_format = "{:.2f}".format
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %%
# %load_ext autoreload
# %autoreload 2
# %aimport utils.plot_utils
# %aimport utils.eda_utils
# %aimport utils.style_utils
# %aimport utils.psi
# %aimport utils.style.styler

# %% [markdown]
# # Входные данные

# %% [markdown]
# ## Загрузка данных

# %%
data = pd.read_parquet('./data/processed/data.pqt')

data.shape
# Out:
# (1097231, 494)

# %% [markdown]
# ## Валидные переменные

# %%
path = r'./docs/valid_features.xlsx'
valid_features_data = pd.read_excel(path, index_col=False)

# %% [markdown]
# ## Конфиги/константы

# %%
TARGET = 'target'
DATE_MONTH = 'date_month'
DATE_QUARTAL = 'date_quartal'
RANDOM_STATE = 42

FEATURES = valid_features_data.loc[(valid_features_data['valid_flag'] == 1)]['attribute'].values
CAT_FEATURES = list(set(FEATURES) & set(data.select_dtypes(include=["object", "category"]).columns))
NUM_FEATURES = list(set(FEATURES) & set(data.select_dtypes(include=["number"]).columns))

TRAIN_MASK = (data['sample_type'] == 'TRAIN')
TEST_MASK = (data['sample_type'] == 'TEST')
OOT_MASK = (data['sample_type'] == 'OOT')

DEV_MASK = (data['competition_sample_type'] == 'TRAIN')

# %%
print_multiple_html(
    ('Кол-во переменных: ', len(FEATURES)),
    ('Кол-во категориальных переменных: ', len(CAT_FEATURES))
)
# Out:
# <div style='margin-bottom: 1.4px;'>
#                 <b style='white-space: pre;'>Кол-во переменных: </b>
#                 <b style='color:orange;'>371</b>
#             </div><div style='margin-bottom: 1.4px;'>
#                 <b style='white-space: pre;'>Кол-во категориальных переменных: </b>
#                 <b style='color:orange;'>16</b>
#             </div>

# %%
metr_funcs = {
    'roc_auc': metric_funcs.roc_auc_score_nan,
    'gini': metric_funcs.gini_score_nan,
}

stats_funcs = {
    'obs_cnt': lambda y_true, data: len(y_true),
    'target_cnt': lambda y_true, data: sum(y_true),
    'DR': lambda y_true, data: sum(y_true) / len(y_true)
}

# Класс для расчета метрик
metr_calc = MetricCalculator(metr_funcs=metr_funcs, stats_funcs=stats_funcs)


STYLE_CONFIG = {
    'percent_cols': ['gini', 'roc_auc', 'DR'],
    'int_cols': ['obs_cnt', 'target_cnt'],
    'gradient_cols': ['gini', 'roc_auc'],
    'gradient_cmap': 'RdYlGn',
}

# %%
def metrics_split(data, group_cols, metr_calc, pred_cols=['lg_model_preds'], target='target', asc=True):
    """Упрощенный интерфес для расчета метрик"""

    metr_split = metr_calc.calculate(data, true_col=target, pred_cols=pred_cols, group_cols=group_cols)
    metr_split = (
        metr_split
        .sort_values(by=group_cols, ascending=asc)
        .set_index(group_cols)
    )
    
    return metr_split

# %% [markdown]
# # Обучение LogReg

# %%
default_params = {
    'penalty': 'l1',
    'dual': False,
    'tol': 0.0001,
    'C': 1.0,
    'fit_intercept': True,
    'intercept_scaling': 1,
    'solver': 'saga',
    'max_iter': 100,
    'random_state': 42,
}


preprocessor = ColumnTransformer(
    transformers=[
        ('num', Pipeline([
            ('imputer', SimpleImputer(strategy='median')),
            ('scaler', StandardScaler())
        ]), NUM_FEATURES),
        ('cat', CatBoostEncoder(), CAT_FEATURES),
    ], 
    remainder='passthrough'
)

pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('model', LogisticRegression(**default_params))
])

pipeline.fit(data.loc[TRAIN_MASK][FEATURES], data.loc[TRAIN_MASK][TARGET])
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['V137', 'C8',
#                                                    'TransactionAmt', 'V258',
#                                                    'V161', 'V248', 'V155',
#                                                    'V164', 'C10', 'D15', 'V4',
#                                                    'V194', 'V34', 'V29', 'V229',
#                                                    'V338', 'V251', 'V312',
#                                                    'V187', 'hour_sin', 'V268',
#                                                    'V162', 'V231', 'V279',
#                                                    'V196', 'V95', 'V64', 'V195',
#                                                    'V204', 'V174', ...]),
#                                                  ('cat', CatBoostEncoder(),
#                                                   ['M4', 'M8', 'M7', 'M5', 'M1',
#                                                    'P_emaildomain',
#                                                    'DeviceType', 'DeviceInfo',
#                                                    'M3', 'R_emaildomain', 'M9',
#                                                    'M6', 'M2', 'card6', 'card4',
#                                                    'ProductCD'])])),
#                 ('model',
#                  LogisticRegression(penalty='l1', random_state=42,
#                                     solver='saga'))])

# %%
data['lg_model_preds'] = pipeline.predict_proba(data[FEATURES])[:, 1]

# %% [markdown]
# ## Метрики базовой модели

# %%
metr_split = metrics_split(
    data=data.loc[DEV_MASK],
    target=TARGET,
    pred_cols='lg_model_preds',
    group_cols='sample_type',
    metr_calc=metr_calc,
    asc=False
)

style_metrics(metr_split, STYLE_CONFIG)
# Out:
# <style type="text/css">
# #T_64d32_row0_col1, #T_64d32_row0_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_64d32_row1_col1, #T_64d32_row1_col2 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_64d32_row2_col1, #T_64d32_row2_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_64d32">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64d32_level0_col0" class="col_heading level0 col0" >level_1</th>
#       <th id="T_64d32_level0_col1" class="col_heading level0 col1" >roc_auc</th>
#       <th id="T_64d32_level0_col2" class="col_heading level0 col2" >gini</th>
#       <th id="T_64d32_level0_col3" class="col_heading level0 col3" >obs_cnt</th>
#       <th id="T_64d32_level0_col4" class="col_heading level0 col4" >target_cnt</th>
#       <th id="T_64d32_level0_col5" class="col_heading level0 col5" >DR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sample_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64d32_level0_row0" class="row_heading level0 row0" >TRAIN</th>
#       <td id="T_64d32_row0_col0" class="data row0 col0" >lg_model_preds</td>
#       <td id="T_64d32_row0_col1" class="data row0 col1" >83.0%</td>
#       <td id="T_64d32_row0_col2" class="data row0 col2" >66.1%</td>
#       <td id="T_64d32_row0_col3" class="data row0 col3" >350 849</td>
#       <td id="T_64d32_row0_col4" class="data row0 col4" >12 166</td>
#       <td id="T_64d32_row0_col5" class="data row0 col5" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_64d32_level0_row1" class="row_heading level0 row1" >TEST</th>
#       <td id="T_64d32_row1_col0" class="data row1 col0" >lg_model_preds</td>
#       <td id="T_64d32_row1_col1" class="data row1 col1" >82.8%</td>
#       <td id="T_64d32_row1_col2" class="data row1 col2" >65.5%</td>
#       <td id="T_64d32_row1_col3" class="data row1 col3" >150 365</td>
#       <td id="T_64d32_row1_col4" class="data row1 col4" >5 383</td>
#       <td id="T_64d32_row1_col5" class="data row1 col5" >3.6%</td>
#     </tr>
#     <tr>
#       <th id="T_64d32_level0_row2" class="row_heading level0 row2" >OOT</th>
#       <td id="T_64d32_row2_col0" class="data row2 col0" >lg_model_preds</td>
#       <td id="T_64d32_row2_col1" class="data row2 col1" >81.1%</td>
#       <td id="T_64d32_row2_col2" class="data row2 col2" >62.2%</td>
#       <td id="T_64d32_row2_col3" class="data row2 col3" >89 326</td>
#       <td id="T_64d32_row2_col4" class="data row2 col4" >3 114</td>
#       <td id="T_64d32_row2_col5" class="data row2 col5" >3.5%</td>
#     </tr>
#   </tbody>
# </table>

# %%
metr_split = metrics_split(
    data=data.loc[DEV_MASK],
    target=TARGET,
    pred_cols='lg_model_preds',
    group_cols=DATE_MONTH,
    metr_calc=metr_calc,
    asc=True
)

style_metrics(metr_split, STYLE_CONFIG)
# Out:
# <style type="text/css">
# #T_ac8aa_row0_col1, #T_ac8aa_row0_col2 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_ac8aa_row1_col1, #T_ac8aa_row1_col2 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_ac8aa_row2_col1, #T_ac8aa_row2_col2 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_ac8aa_row3_col1, #T_ac8aa_row3_col2 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_ac8aa_row4_col1, #T_ac8aa_row4_col2 {
#   background-color: #e0422f;
#   color: #f1f1f1;
# }
# #T_ac8aa_row5_col1, #T_ac8aa_row5_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_ac8aa_row6_col1, #T_ac8aa_row6_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ac8aa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac8aa_level0_col0" class="col_heading level0 col0" >level_1</th>
#       <th id="T_ac8aa_level0_col1" class="col_heading level0 col1" >roc_auc</th>
#       <th id="T_ac8aa_level0_col2" class="col_heading level0 col2" >gini</th>
#       <th id="T_ac8aa_level0_col3" class="col_heading level0 col3" >obs_cnt</th>
#       <th id="T_ac8aa_level0_col4" class="col_heading level0 col4" >target_cnt</th>
#       <th id="T_ac8aa_level0_col5" class="col_heading level0 col5" >DR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >date_month</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac8aa_level0_row0" class="row_heading level0 row0" >2020-01</th>
#       <td id="T_ac8aa_row0_col0" class="data row0 col0" >lg_model_preds</td>
#       <td id="T_ac8aa_row0_col1" class="data row0 col1" >81.6%</td>
#       <td id="T_ac8aa_row0_col2" class="data row0 col2" >63.3%</td>
#       <td id="T_ac8aa_row0_col3" class="data row0 col3" >134 339</td>
#       <td id="T_ac8aa_row0_col4" class="data row0 col4" >3 401</td>
#       <td id="T_ac8aa_row0_col5" class="data row0 col5" >2.5%</td>
#     </tr>
#     <tr>
#       <th id="T_ac8aa_level0_row1" class="row_heading level0 row1" >2020-02</th>
#       <td id="T_ac8aa_row1_col0" class="data row1 col0" >lg_model_preds</td>
#       <td id="T_ac8aa_row1_col1" class="data row1 col1" >84.5%</td>
#       <td id="T_ac8aa_row1_col2" class="data row1 col2" >68.9%</td>
#       <td id="T_ac8aa_row1_col3" class="data row1 col3" >86 467</td>
#       <td id="T_ac8aa_row1_col4" class="data row1 col4" >3 469</td>
#       <td id="T_ac8aa_row1_col5" class="data row1 col5" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_ac8aa_level0_row2" class="row_heading level0 row2" >2020-03</th>
#       <td id="T_ac8aa_row2_col0" class="data row2 col0" >lg_model_preds</td>
#       <td id="T_ac8aa_row2_col1" class="data row2 col1" >84.1%</td>
#       <td id="T_ac8aa_row2_col2" class="data row2 col2" >68.3%</td>
#       <td id="T_ac8aa_row2_col3" class="data row2 col3" >95 121</td>
#       <td id="T_ac8aa_row2_col4" class="data row2 col4" >3 832</td>
#       <td id="T_ac8aa_row2_col5" class="data row2 col5" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_ac8aa_level0_row3" class="row_heading level0 row3" >2020-04</th>
#       <td id="T_ac8aa_row3_col0" class="data row3 col0" >lg_model_preds</td>
#       <td id="T_ac8aa_row3_col1" class="data row3 col1" >83.3%</td>
#       <td id="T_ac8aa_row3_col2" class="data row3 col2" >66.5%</td>
#       <td id="T_ac8aa_row3_col3" class="data row3 col3" >98 615</td>
#       <td id="T_ac8aa_row3_col4" class="data row3 col4" >3 898</td>
#       <td id="T_ac8aa_row3_col5" class="data row3 col5" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_ac8aa_level0_row4" class="row_heading level0 row4" >2020-05</th>
#       <td id="T_ac8aa_row4_col0" class="data row4 col0" >lg_model_preds</td>
#       <td id="T_ac8aa_row4_col1" class="data row4 col1" >81.6%</td>
#       <td id="T_ac8aa_row4_col2" class="data row4 col2" >63.2%</td>
#       <td id="T_ac8aa_row4_col3" class="data row4 col3" >86 672</td>
#       <td id="T_ac8aa_row4_col4" class="data row4 col4" >2 949</td>
#       <td id="T_ac8aa_row4_col5" class="data row4 col5" >3.4%</td>
#     </tr>
#     <tr>
#       <th id="T_ac8aa_level0_row5" class="row_heading level0 row5" >2020-06</th>
#       <td id="T_ac8aa_row5_col0" class="data row5 col0" >lg_model_preds</td>
#       <td id="T_ac8aa_row5_col1" class="data row5 col1" >80.9%</td>
#       <td id="T_ac8aa_row5_col2" class="data row5 col2" >61.8%</td>
#       <td id="T_ac8aa_row5_col3" class="data row5 col3" >86 572</td>
#       <td id="T_ac8aa_row5_col4" class="data row5 col4" >2 995</td>
#       <td id="T_ac8aa_row5_col5" class="data row5 col5" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_ac8aa_level0_row6" class="row_heading level0 row6" >2020-07</th>
#       <td id="T_ac8aa_row6_col0" class="data row6 col0" >lg_model_preds</td>
#       <td id="T_ac8aa_row6_col1" class="data row6 col1" >86.1%</td>
#       <td id="T_ac8aa_row6_col2" class="data row6 col2" >72.1%</td>
#       <td id="T_ac8aa_row6_col3" class="data row6 col3" >2 754</td>
#       <td id="T_ac8aa_row6_col4" class="data row6 col4" >119</td>
#       <td id="T_ac8aa_row6_col5" class="data row6 col5" >4.3%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Графики распределения таргета по выборкам
fig, axes = plt.subplots(1, 2, figsize=(16, 4), gridspec_kw={'width_ratios': [1, 1.7]})
masks_dict = {'TRAIN': TRAIN_MASK, 'TEST': TEST_MASK, 'OOT': OOT_MASK}

ax = axes[0]
plot_roc_by_masks(data, TARGET, 'lg_model_preds', masks_dict, 
                     figsize=(8, 4), palette='bright', 
                     title='ROC-кривые по различным подвыборкам',
                     ax=ax)

ax = axes[1]
plot_gini_by_period_styled(metr_split.reset_index(), 'gini', DATE_MONTH,
                              figsize=(8, 4), 
                              target_gini=40,
                              title='Динамика Gini по периодам',
                              ax=ax)

# %% [markdown]
# # Обучение CatBoost

# %%
# Берем только наблюдения с взаимной целевой и преобразуем кат. фичи
dev_sample = data.loc[DEV_MASK].copy()

# Трансформируем категориальные переменные
dev_sample = CustomPreprocessor(cat_features=CAT_FEATURES).transform(dev_sample)

# %%
train_pool = get_pool(dev_sample, TARGET, TRAIN_MASK, FEATURES, CAT_FEATURES)
test_pool = get_pool(dev_sample, TARGET, TEST_MASK, FEATURES, CAT_FEATURES)
oot_pool = get_pool(dev_sample, TARGET, OOT_MASK, FEATURES, CAT_FEATURES)

# %%
# Параметры модели
default_params = {
    "iterations": 100,
    "loss_function": "Logloss",
    "eval_metric": "AUC",
    "early_stopping_rounds": 20,
    "verbose": 0,
    "random_seed": 42,
}

# %%
# Обучение модели
model = CatBoostClassifier(**default_params, cat_features=CAT_FEATURES)
model.fit(train_pool, eval_set=test_pool, use_best_model=True, plot=False)

# %%
# Предсказания для всего набора
pipeline = Pipeline([
    ('preprocessor', CustomPreprocessor(cat_features=CAT_FEATURES)),
    ('model', model),
])

data['cb_model_preds'] = pipeline.predict_proba(data[FEATURES])[:, 1]

# %% [markdown]
# ## Метрики

# %%
metr_split = metrics_split(
    data=data.loc[DEV_MASK],
    target=TARGET,
    pred_cols='cb_model_preds',
    group_cols='sample_type',
    metr_calc=metr_calc,
    asc=False
)

style_metrics(metr_split, STYLE_CONFIG)
# Out:
# <style type="text/css">
# #T_a004c_row0_col1, #T_a004c_row0_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_a004c_row1_col1, #T_a004c_row1_col2 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_a004c_row2_col1, #T_a004c_row2_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a004c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a004c_level0_col0" class="col_heading level0 col0" >level_1</th>
#       <th id="T_a004c_level0_col1" class="col_heading level0 col1" >roc_auc</th>
#       <th id="T_a004c_level0_col2" class="col_heading level0 col2" >gini</th>
#       <th id="T_a004c_level0_col3" class="col_heading level0 col3" >obs_cnt</th>
#       <th id="T_a004c_level0_col4" class="col_heading level0 col4" >target_cnt</th>
#       <th id="T_a004c_level0_col5" class="col_heading level0 col5" >DR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sample_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a004c_level0_row0" class="row_heading level0 row0" >TRAIN</th>
#       <td id="T_a004c_row0_col0" class="data row0 col0" >cb_model_preds</td>
#       <td id="T_a004c_row0_col1" class="data row0 col1" >91.7%</td>
#       <td id="T_a004c_row0_col2" class="data row0 col2" >83.4%</td>
#       <td id="T_a004c_row0_col3" class="data row0 col3" >350 849</td>
#       <td id="T_a004c_row0_col4" class="data row0 col4" >12 166</td>
#       <td id="T_a004c_row0_col5" class="data row0 col5" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_a004c_level0_row1" class="row_heading level0 row1" >TEST</th>
#       <td id="T_a004c_row1_col0" class="data row1 col0" >cb_model_preds</td>
#       <td id="T_a004c_row1_col1" class="data row1 col1" >90.9%</td>
#       <td id="T_a004c_row1_col2" class="data row1 col2" >81.8%</td>
#       <td id="T_a004c_row1_col3" class="data row1 col3" >150 365</td>
#       <td id="T_a004c_row1_col4" class="data row1 col4" >5 383</td>
#       <td id="T_a004c_row1_col5" class="data row1 col5" >3.6%</td>
#     </tr>
#     <tr>
#       <th id="T_a004c_level0_row2" class="row_heading level0 row2" >OOT</th>
#       <td id="T_a004c_row2_col0" class="data row2 col0" >cb_model_preds</td>
#       <td id="T_a004c_row2_col1" class="data row2 col1" >88.5%</td>
#       <td id="T_a004c_row2_col2" class="data row2 col2" >76.9%</td>
#       <td id="T_a004c_row2_col3" class="data row2 col3" >89 326</td>
#       <td id="T_a004c_row2_col4" class="data row2 col4" >3 114</td>
#       <td id="T_a004c_row2_col5" class="data row2 col5" >3.5%</td>
#     </tr>
#   </tbody>
# </table>

# %%
metr_split = metrics_split(
    data=data.loc[DEV_MASK],
    target=TARGET,
    pred_cols='cb_model_preds',
    group_cols=DATE_MONTH,
    metr_calc=metr_calc,
    asc=True
)

style_metrics(metr_split, STYLE_CONFIG)
# Out:
# <style type="text/css">
# #T_061ad_row0_col1, #T_061ad_row0_col2 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_061ad_row1_col1, #T_061ad_row1_col2 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_061ad_row2_col1, #T_061ad_row2_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_061ad_row3_col1, #T_061ad_row3_col2 {
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_061ad_row4_col1, #T_061ad_row4_col2 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_061ad_row5_col1, #T_061ad_row5_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_061ad_row6_col1, #T_061ad_row6_col2 {
#   background-color: #fede89;
#   color: #000000;
# }
# </style>
# <table id="T_061ad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_061ad_level0_col0" class="col_heading level0 col0" >level_1</th>
#       <th id="T_061ad_level0_col1" class="col_heading level0 col1" >roc_auc</th>
#       <th id="T_061ad_level0_col2" class="col_heading level0 col2" >gini</th>
#       <th id="T_061ad_level0_col3" class="col_heading level0 col3" >obs_cnt</th>
#       <th id="T_061ad_level0_col4" class="col_heading level0 col4" >target_cnt</th>
#       <th id="T_061ad_level0_col5" class="col_heading level0 col5" >DR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >date_month</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_061ad_level0_row0" class="row_heading level0 row0" >2020-01</th>
#       <td id="T_061ad_row0_col0" class="data row0 col0" >cb_model_preds</td>
#       <td id="T_061ad_row0_col1" class="data row0 col1" >91.1%</td>
#       <td id="T_061ad_row0_col2" class="data row0 col2" >82.1%</td>
#       <td id="T_061ad_row0_col3" class="data row0 col3" >134 339</td>
#       <td id="T_061ad_row0_col4" class="data row0 col4" >3 401</td>
#       <td id="T_061ad_row0_col5" class="data row0 col5" >2.5%</td>
#     </tr>
#     <tr>
#       <th id="T_061ad_level0_row1" class="row_heading level0 row1" >2020-02</th>
#       <td id="T_061ad_row1_col0" class="data row1 col0" >cb_model_preds</td>
#       <td id="T_061ad_row1_col1" class="data row1 col1" >91.9%</td>
#       <td id="T_061ad_row1_col2" class="data row1 col2" >83.7%</td>
#       <td id="T_061ad_row1_col3" class="data row1 col3" >86 467</td>
#       <td id="T_061ad_row1_col4" class="data row1 col4" >3 469</td>
#       <td id="T_061ad_row1_col5" class="data row1 col5" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_061ad_level0_row2" class="row_heading level0 row2" >2020-03</th>
#       <td id="T_061ad_row2_col0" class="data row2 col0" >cb_model_preds</td>
#       <td id="T_061ad_row2_col1" class="data row2 col1" >92.1%</td>
#       <td id="T_061ad_row2_col2" class="data row2 col2" >84.1%</td>
#       <td id="T_061ad_row2_col3" class="data row2 col3" >95 121</td>
#       <td id="T_061ad_row2_col4" class="data row2 col4" >3 832</td>
#       <td id="T_061ad_row2_col5" class="data row2 col5" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_061ad_level0_row3" class="row_heading level0 row3" >2020-04</th>
#       <td id="T_061ad_row3_col0" class="data row3 col0" >cb_model_preds</td>
#       <td id="T_061ad_row3_col1" class="data row3 col1" >91.1%</td>
#       <td id="T_061ad_row3_col2" class="data row3 col2" >82.2%</td>
#       <td id="T_061ad_row3_col3" class="data row3 col3" >98 615</td>
#       <td id="T_061ad_row3_col4" class="data row3 col4" >3 898</td>
#       <td id="T_061ad_row3_col5" class="data row3 col5" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_061ad_level0_row4" class="row_heading level0 row4" >2020-05</th>
#       <td id="T_061ad_row4_col0" class="data row4 col0" >cb_model_preds</td>
#       <td id="T_061ad_row4_col1" class="data row4 col1" >91.1%</td>
#       <td id="T_061ad_row4_col2" class="data row4 col2" >82.3%</td>
#       <td id="T_061ad_row4_col3" class="data row4 col3" >86 672</td>
#       <td id="T_061ad_row4_col4" class="data row4 col4" >2 949</td>
#       <td id="T_061ad_row4_col5" class="data row4 col5" >3.4%</td>
#     </tr>
#     <tr>
#       <th id="T_061ad_level0_row5" class="row_heading level0 row5" >2020-06</th>
#       <td id="T_061ad_row5_col0" class="data row5 col0" >cb_model_preds</td>
#       <td id="T_061ad_row5_col1" class="data row5 col1" >88.4%</td>
#       <td id="T_061ad_row5_col2" class="data row5 col2" >76.8%</td>
#       <td id="T_061ad_row5_col3" class="data row5 col3" >86 572</td>
#       <td id="T_061ad_row5_col4" class="data row5 col4" >2 995</td>
#       <td id="T_061ad_row5_col5" class="data row5 col5" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_061ad_level0_row6" class="row_heading level0 row6" >2020-07</th>
#       <td id="T_061ad_row6_col0" class="data row6 col0" >cb_model_preds</td>
#       <td id="T_061ad_row6_col1" class="data row6 col1" >89.9%</td>
#       <td id="T_061ad_row6_col2" class="data row6 col2" >79.7%</td>
#       <td id="T_061ad_row6_col3" class="data row6 col3" >2 754</td>
#       <td id="T_061ad_row6_col4" class="data row6 col4" >119</td>
#       <td id="T_061ad_row6_col5" class="data row6 col5" >4.3%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Графики распределения таргета по выборкам
fig, axes = plt.subplots(1, 2, figsize=(16, 4), gridspec_kw={'width_ratios': [1, 1.7]})
masks_dict = {'TRAIN': TRAIN_MASK, 'TEST': TEST_MASK, 'OOT': OOT_MASK}

ax = axes[0]
plot_roc_by_masks(data, TARGET, 'lg_model_preds', masks_dict, 
                     figsize=(8, 4), palette='bright', 
                     title='ROC-кривые по различным подвыборкам',
                     ax=ax)

ax = axes[1]
plot_gini_by_period_styled(metr_split.reset_index(), 'gini', DATE_MONTH,
                              figsize=(8, 4), 
                              target_gini=40,
                              title='Динамика Gini по периодам',
                              ax=ax)

# %% [markdown]
# # Сравнение моделей

# %%
metr_split = metrics_split(
    data=data.loc[DEV_MASK],
    target=TARGET,
    pred_cols=['cb_model_preds', 'lg_model_preds'],
    group_cols='sample_type',
    metr_calc=metr_calc,
    asc=False
)

style_metrics(metr_split.reset_index(), STYLE_CONFIG)
# Out:
# <style type="text/css">
# #T_d9bc1_row0_col2, #T_d9bc1_row0_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_d9bc1_row1_col2, #T_d9bc1_row1_col3 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_d9bc1_row2_col2, #T_d9bc1_row2_col3 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_d9bc1_row3_col2, #T_d9bc1_row3_col3 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_d9bc1_row4_col2, #T_d9bc1_row4_col3 {
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_d9bc1_row5_col2, #T_d9bc1_row5_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d9bc1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9bc1_level0_col0" class="col_heading level0 col0" >sample_type</th>
#       <th id="T_d9bc1_level0_col1" class="col_heading level0 col1" >level_1</th>
#       <th id="T_d9bc1_level0_col2" class="col_heading level0 col2" >roc_auc</th>
#       <th id="T_d9bc1_level0_col3" class="col_heading level0 col3" >gini</th>
#       <th id="T_d9bc1_level0_col4" class="col_heading level0 col4" >obs_cnt</th>
#       <th id="T_d9bc1_level0_col5" class="col_heading level0 col5" >target_cnt</th>
#       <th id="T_d9bc1_level0_col6" class="col_heading level0 col6" >DR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9bc1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d9bc1_row0_col0" class="data row0 col0" >TRAIN</td>
#       <td id="T_d9bc1_row0_col1" class="data row0 col1" >cb_model_preds</td>
#       <td id="T_d9bc1_row0_col2" class="data row0 col2" >91.7%</td>
#       <td id="T_d9bc1_row0_col3" class="data row0 col3" >83.4%</td>
#       <td id="T_d9bc1_row0_col4" class="data row0 col4" >350 849</td>
#       <td id="T_d9bc1_row0_col5" class="data row0 col5" >12 166</td>
#       <td id="T_d9bc1_row0_col6" class="data row0 col6" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_d9bc1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d9bc1_row1_col0" class="data row1 col0" >TRAIN</td>
#       <td id="T_d9bc1_row1_col1" class="data row1 col1" >lg_model_preds</td>
#       <td id="T_d9bc1_row1_col2" class="data row1 col2" >83.0%</td>
#       <td id="T_d9bc1_row1_col3" class="data row1 col3" >66.1%</td>
#       <td id="T_d9bc1_row1_col4" class="data row1 col4" >350 849</td>
#       <td id="T_d9bc1_row1_col5" class="data row1 col5" >12 166</td>
#       <td id="T_d9bc1_row1_col6" class="data row1 col6" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_d9bc1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d9bc1_row2_col0" class="data row2 col0" >TEST</td>
#       <td id="T_d9bc1_row2_col1" class="data row2 col1" >cb_model_preds</td>
#       <td id="T_d9bc1_row2_col2" class="data row2 col2" >90.9%</td>
#       <td id="T_d9bc1_row2_col3" class="data row2 col3" >81.8%</td>
#       <td id="T_d9bc1_row2_col4" class="data row2 col4" >150 365</td>
#       <td id="T_d9bc1_row2_col5" class="data row2 col5" >5 383</td>
#       <td id="T_d9bc1_row2_col6" class="data row2 col6" >3.6%</td>
#     </tr>
#     <tr>
#       <th id="T_d9bc1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d9bc1_row3_col0" class="data row3 col0" >TEST</td>
#       <td id="T_d9bc1_row3_col1" class="data row3 col1" >lg_model_preds</td>
#       <td id="T_d9bc1_row3_col2" class="data row3 col2" >82.8%</td>
#       <td id="T_d9bc1_row3_col3" class="data row3 col3" >65.5%</td>
#       <td id="T_d9bc1_row3_col4" class="data row3 col4" >150 365</td>
#       <td id="T_d9bc1_row3_col5" class="data row3 col5" >5 383</td>
#       <td id="T_d9bc1_row3_col6" class="data row3 col6" >3.6%</td>
#     </tr>
#     <tr>
#       <th id="T_d9bc1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d9bc1_row4_col0" class="data row4 col0" >OOT</td>
#       <td id="T_d9bc1_row4_col1" class="data row4 col1" >cb_model_preds</td>
#       <td id="T_d9bc1_row4_col2" class="data row4 col2" >88.5%</td>
#       <td id="T_d9bc1_row4_col3" class="data row4 col3" >76.9%</td>
#       <td id="T_d9bc1_row4_col4" class="data row4 col4" >89 326</td>
#       <td id="T_d9bc1_row4_col5" class="data row4 col5" >3 114</td>
#       <td id="T_d9bc1_row4_col6" class="data row4 col6" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_d9bc1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d9bc1_row5_col0" class="data row5 col0" >OOT</td>
#       <td id="T_d9bc1_row5_col1" class="data row5 col1" >lg_model_preds</td>
#       <td id="T_d9bc1_row5_col2" class="data row5 col2" >81.1%</td>
#       <td id="T_d9bc1_row5_col3" class="data row5 col3" >62.2%</td>
#       <td id="T_d9bc1_row5_col4" class="data row5 col4" >89 326</td>
#       <td id="T_d9bc1_row5_col5" class="data row5 col5" >3 114</td>
#       <td id="T_d9bc1_row5_col6" class="data row5 col6" >3.5%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Отбор переменных

# %%
importances_df = pd.DataFrame({
    'Feature': model.feature_names_,
    'Importance': model.get_feature_importance()
}).sort_values('Importance', ascending=False)

importances_df.head(8)
# Out:
#             Feature  Importance
# 24              C13        5.46
# 319            V294        3.69
# 7             card6        3.57
# 13               C1        3.56
# 3             card2        3.38
# 25              C14        3.24
# 131             V91        3.22
# 0    TransactionAmt        2.89

# %%
# Далее используем важные переменные
IMP_SHORT_FEATURES = importances_df[importances_df['Importance'] > 0.01]['Feature'].to_list()
IMP_CAT_FEATURES = [i for i in CAT_FEATURES if i in IMP_SHORT_FEATURES]

print_multiple_html(
    (f"Кол-во важных фичей (total): ", len(IMP_SHORT_FEATURES)),
    (f"Кол-во важных категориальных фичей: ", len(IMP_CAT_FEATURES)),
)
# Out:
# <div style='margin-bottom: 1.4px;'>
#                 <b style='white-space: pre;'>Кол-во важных фичей (total): </b>
#                 <b style='color:orange;'>191</b>
#             </div><div style='margin-bottom: 1.4px;'>
#                 <b style='white-space: pre;'>Кол-во важных категориальных фичей: </b>
#                 <b style='color:orange;'>12</b>
#             </div>

# %%
# Для простоты берем топ-30
FINAL_FEATURES = importances_df.loc[importances_df['Feature'].isin(IMP_SHORT_FEATURES)][:30]['Feature'].to_list()
FINAL_CAT_FEATURES = [i for i in IMP_CAT_FEATURES if i in FINAL_FEATURES]

# %%
print_multiple_html(
    (f"Кол-во финальных фичей: ", len(FINAL_FEATURES)),
    (f"Кол-во финальных категориальных фичей: ", len(FINAL_CAT_FEATURES)),
)
# Out:
# <div style='margin-bottom: 1.4px;'>
#                 <b style='white-space: pre;'>Кол-во финальных фичей: </b>
#                 <b style='color:orange;'>30</b>
#             </div><div style='margin-bottom: 1.4px;'>
#                 <b style='white-space: pre;'>Кол-во финальных категориальных фичей: </b>
#                 <b style='color:orange;'>7</b>
#             </div>

# %%
# Сохраняем переменные
features = {
    'FINAL_FEATURES': FINAL_FEATURES,
    'FINAL_CAT_FEATURES': FINAL_CAT_FEATURES
}

with open(r'./models/params/features.yaml', 'w', encoding='utf-8') as file:
    yaml.dump(features, file, allow_unicode=True, default_flow_style=False)

# %% [markdown]
# # Подбор гиперпараметров

# %%
# Обновляем пулы данных
train_pool = get_pool(dev_sample, TARGET, TRAIN_MASK, FINAL_FEATURES, FINAL_CAT_FEATURES)
test_pool = get_pool(dev_sample, TARGET, TEST_MASK, FINAL_FEATURES, FINAL_CAT_FEATURES)
oot_pool = get_pool(dev_sample, TARGET, OOT_MASK, FINAL_FEATURES, FINAL_CAT_FEATURES)

# %%
def objective(trial):
    params = {
        'iterations':trial.suggest_int("iterations", 100, 500),                                # Количество деревьев в бустинге
        'depth': trial.suggest_int('depth', 4, 7),                                             # Глубина деревьев
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),            # Скорость обучения
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 0.1),              # Выборка признаков на каждом уровне дерева 
        'verbose': False,
        'random_state': 42
    }

    catboost = CatBoostClassifier(**params)
    catboost.fit(train_pool, plot=False)
    
    roc_auc = roc_auc_score(data[TEST_MASK][TARGET], catboost.predict_proba(test_pool)[:, 1])
    return roc_auc

# %%
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=10, show_progress_bar=False)
# Out:
# [I 2025-12-03 12:22:57,587] A new study created in memory with name: no-name-6a66ed98-82fe-464e-9d3c-58266f70fe60
# [I 2025-12-03 12:23:28,772] Trial 0 finished with value: 0.9048330714133531 and parameters: {'iterations': 250, 'depth': 7, 'learning_rate': 0.1205712628744377, 'colsample_bylevel': 0.0638792635777333}. Best is trial 0 with value: 0.9048330714133531.
# [I 2025-12-03 12:23:47,929] Trial 1 finished with value: 0.8392748508361533 and parameters: {'iterations': 162, 'depth': 4, 'learning_rate': 0.012184186502221764, 'colsample_bylevel': 0.08795585311974417}. Best is trial 0 with value: 0.9048330714133531.
# [I 2025-12-03 12:24:29,348] Trial 2 finished with value: 0.8683154176995044 and parameters: {'iterations': 341, 'depth': 6, 'learning_rate': 0.010725209743171997, 'colsample_bylevel': 0.0972918866945795}. Best is trial 0 with value: 0.9048330714133531.
# [I 2025-12-03 12:25:05,429] Trial 3 finished with value: 0.8428459053228239 and parameters: {'iterations': 433, 'depth': 4, 'learning_rate': 0.01855998084649058, 'colsample_bylevel': 0.026506405886809047}. Best is trial 0 with value: 0.9048330714133531.
# [I 2025-12-03 12:25:24,075] Trial 4 finished with value: 0.8660685482981786 and parameters: {'iterations': 222, 'depth': 6, 'learning_rate': 0.04345454109729477, 'colsample_bylevel': 0.036210622617823776}. Best is trial 0 with value: 0.9048330714133531.
# [I 2025-12-03 12:25:53,017] Trial 5 finished with value: 0.8633035814373728 and parameters: {'iterations': 345, 'depth': 4, 'learning_rate': 0.027010527749605478, 'colsample_bylevel': 0.04297256589643226}. Best is trial 0 with value: 0.9048330714133531.
# [I 2025-12-03 12:26:24,178] Trial 6 finished with value: 0.872303572526993 and parameters: {'iterations': 282, 'depth': 7, 'learning_rate': 0.019721610970574007, 'colsample_bylevel': 0.05628109945722505}. Best is trial 0 with value: 0.9048330714133531.
# [I 2025-12-03 12:26:51,385] Trial 7 finished with value: 0.8672237359973298 and parameters: {'iterations': 337, 'depth': 4, 'learning_rate': 0.07896186801026692, 'colsample_bylevel': 0.02534717113185624}. Best is trial 0 with value: 0.9048330714133531.
# [I 2025-12-03 12:27:07,084] Trial 8 finished with value: 0.9029926102813848 and parameters: {'iterations': 126, 'depth': 7, 'learning_rate': 0.26690431824362526, 'colsample_bylevel': 0.08275576133048151}. Best is trial 0 with value: 0.9048330714133531.
# [I 2025-12-03 12:27:33,688] Trial 9 finished with value: 0.8804729173488102 and parameters: {'iterations': 222, 'depth': 4, 'learning_rate': 0.1024932221692416, 'colsample_bylevel': 0.04961372443656412}. Best is trial 0 with value: 0.9048330714133531.

# %%
final_params = {**default_params, **study.best_params}
final_params
# Out:
# {'iterations': 250,
#  'loss_function': 'Logloss',
#  'eval_metric': 'AUC',
#  'early_stopping_rounds': 20,
#  'verbose': 0,
#  'random_seed': 42,
#  'depth': 7,
#  'learning_rate': 0.1205712628744377,
#  'colsample_bylevel': 0.0638792635777333}

# %%
# Сохраняем параметры
with open(r'./models/params/best_params.yaml', 'w', encoding='utf-8') as file:
    yaml.dump(final_params, file)

# %% [markdown]
# # Обучение финальной модели

# %%
# Создаем пулы данных
train_pool = get_pool(dev_sample, TARGET, TRAIN_MASK, FINAL_FEATURES, FINAL_CAT_FEATURES)
test_pool = get_pool(dev_sample, TARGET, TEST_MASK, FINAL_FEATURES, FINAL_CAT_FEATURES)
oot_pool = get_pool(dev_sample, TARGET, OOT_MASK, FINAL_FEATURES, FINAL_CAT_FEATURES)

# %%
# Создаем и обучаем модель
final_model = CatBoostClassifier(**final_params, cat_features=FINAL_CAT_FEATURES)
final_model.fit(train_pool, eval_set=test_pool)

# %%
# Предсказания для dev_sample
dev_sample['final_model_preds'] = final_model.predict_proba(dev_sample[FINAL_FEATURES])[:, 1]

# %%
# # Предсказания для всего набора
pipeline = Pipeline([
    ('preprocessor', CustomPreprocessor(cat_features=FINAL_CAT_FEATURES)),
    ('model', final_model),
])

data['final_model_preds'] = pipeline.predict_proba(data[FINAL_FEATURES])[:, 1]

# %% [markdown]
# ## Метрики финальной модели

# %%
metr_split = metrics_split(
    data=data.loc[DEV_MASK],
    target=TARGET,
    pred_cols='final_model_preds',
    group_cols='sample_type',
    metr_calc=metr_calc,
    asc=False
)

style_metrics(metr_split, STYLE_CONFIG)
# Out:
# <style type="text/css">
# #T_4d8b2_row0_col1, #T_4d8b2_row0_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_4d8b2_row1_col1, #T_4d8b2_row1_col2 {
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_4d8b2_row2_col1, #T_4d8b2_row2_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4d8b2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4d8b2_level0_col0" class="col_heading level0 col0" >level_1</th>
#       <th id="T_4d8b2_level0_col1" class="col_heading level0 col1" >roc_auc</th>
#       <th id="T_4d8b2_level0_col2" class="col_heading level0 col2" >gini</th>
#       <th id="T_4d8b2_level0_col3" class="col_heading level0 col3" >obs_cnt</th>
#       <th id="T_4d8b2_level0_col4" class="col_heading level0 col4" >target_cnt</th>
#       <th id="T_4d8b2_level0_col5" class="col_heading level0 col5" >DR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sample_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d8b2_level0_row0" class="row_heading level0 row0" >TRAIN</th>
#       <td id="T_4d8b2_row0_col0" class="data row0 col0" >final_model_preds</td>
#       <td id="T_4d8b2_row0_col1" class="data row0 col1" >91.1%</td>
#       <td id="T_4d8b2_row0_col2" class="data row0 col2" >82.1%</td>
#       <td id="T_4d8b2_row0_col3" class="data row0 col3" >350 849</td>
#       <td id="T_4d8b2_row0_col4" class="data row0 col4" >12 166</td>
#       <td id="T_4d8b2_row0_col5" class="data row0 col5" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_4d8b2_level0_row1" class="row_heading level0 row1" >TEST</th>
#       <td id="T_4d8b2_row1_col0" class="data row1 col0" >final_model_preds</td>
#       <td id="T_4d8b2_row1_col1" class="data row1 col1" >90.5%</td>
#       <td id="T_4d8b2_row1_col2" class="data row1 col2" >81.0%</td>
#       <td id="T_4d8b2_row1_col3" class="data row1 col3" >150 365</td>
#       <td id="T_4d8b2_row1_col4" class="data row1 col4" >5 383</td>
#       <td id="T_4d8b2_row1_col5" class="data row1 col5" >3.6%</td>
#     </tr>
#     <tr>
#       <th id="T_4d8b2_level0_row2" class="row_heading level0 row2" >OOT</th>
#       <td id="T_4d8b2_row2_col0" class="data row2 col0" >final_model_preds</td>
#       <td id="T_4d8b2_row2_col1" class="data row2 col1" >88.3%</td>
#       <td id="T_4d8b2_row2_col2" class="data row2 col2" >76.6%</td>
#       <td id="T_4d8b2_row2_col3" class="data row2 col3" >89 326</td>
#       <td id="T_4d8b2_row2_col4" class="data row2 col4" >3 114</td>
#       <td id="T_4d8b2_row2_col5" class="data row2 col5" >3.5%</td>
#     </tr>
#   </tbody>
# </table>

# %%
metr_split = metrics_split(
    data=data.loc[DEV_MASK],
    target=TARGET,
    pred_cols='final_model_preds',
    group_cols=DATE_MONTH,
    metr_calc=metr_calc,
    asc=True
)

style_metrics(metr_split, STYLE_CONFIG)
# Out:
# <style type="text/css">
# #T_ba982_row0_col1, #T_ba982_row0_col2 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_ba982_row1_col1, #T_ba982_row1_col2 {
#   background-color: #54b45f;
#   color: #f1f1f1;
# }
# #T_ba982_row2_col1, #T_ba982_row2_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_ba982_row3_col1, #T_ba982_row3_col2 {
#   background-color: #b5df74;
#   color: #000000;
# }
# #T_ba982_row4_col1, #T_ba982_row4_col2 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_ba982_row5_col1, #T_ba982_row5_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_ba982_row6_col1, #T_ba982_row6_col2 {
#   background-color: #afdd70;
#   color: #000000;
# }
# </style>
# <table id="T_ba982">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba982_level0_col0" class="col_heading level0 col0" >level_1</th>
#       <th id="T_ba982_level0_col1" class="col_heading level0 col1" >roc_auc</th>
#       <th id="T_ba982_level0_col2" class="col_heading level0 col2" >gini</th>
#       <th id="T_ba982_level0_col3" class="col_heading level0 col3" >obs_cnt</th>
#       <th id="T_ba982_level0_col4" class="col_heading level0 col4" >target_cnt</th>
#       <th id="T_ba982_level0_col5" class="col_heading level0 col5" >DR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >date_month</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba982_level0_row0" class="row_heading level0 row0" >2020-01</th>
#       <td id="T_ba982_row0_col0" class="data row0 col0" >final_model_preds</td>
#       <td id="T_ba982_row0_col1" class="data row0 col1" >90.4%</td>
#       <td id="T_ba982_row0_col2" class="data row0 col2" >80.9%</td>
#       <td id="T_ba982_row0_col3" class="data row0 col3" >134 339</td>
#       <td id="T_ba982_row0_col4" class="data row0 col4" >3 401</td>
#       <td id="T_ba982_row0_col5" class="data row0 col5" >2.5%</td>
#     </tr>
#     <tr>
#       <th id="T_ba982_level0_row1" class="row_heading level0 row1" >2020-02</th>
#       <td id="T_ba982_row1_col0" class="data row1 col0" >final_model_preds</td>
#       <td id="T_ba982_row1_col1" class="data row1 col1" >91.2%</td>
#       <td id="T_ba982_row1_col2" class="data row1 col2" >82.3%</td>
#       <td id="T_ba982_row1_col3" class="data row1 col3" >86 467</td>
#       <td id="T_ba982_row1_col4" class="data row1 col4" >3 469</td>
#       <td id="T_ba982_row1_col5" class="data row1 col5" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_ba982_level0_row2" class="row_heading level0 row2" >2020-03</th>
#       <td id="T_ba982_row2_col0" class="data row2 col0" >final_model_preds</td>
#       <td id="T_ba982_row2_col1" class="data row2 col1" >91.8%</td>
#       <td id="T_ba982_row2_col2" class="data row2 col2" >83.6%</td>
#       <td id="T_ba982_row2_col3" class="data row2 col3" >95 121</td>
#       <td id="T_ba982_row2_col4" class="data row2 col4" >3 832</td>
#       <td id="T_ba982_row2_col5" class="data row2 col5" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_ba982_level0_row3" class="row_heading level0 row3" >2020-04</th>
#       <td id="T_ba982_row3_col0" class="data row3 col0" >final_model_preds</td>
#       <td id="T_ba982_row3_col1" class="data row3 col1" >90.6%</td>
#       <td id="T_ba982_row3_col2" class="data row3 col2" >81.2%</td>
#       <td id="T_ba982_row3_col3" class="data row3 col3" >98 615</td>
#       <td id="T_ba982_row3_col4" class="data row3 col4" >3 898</td>
#       <td id="T_ba982_row3_col5" class="data row3 col5" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_ba982_level0_row4" class="row_heading level0 row4" >2020-05</th>
#       <td id="T_ba982_row4_col0" class="data row4 col0" >final_model_preds</td>
#       <td id="T_ba982_row4_col1" class="data row4 col1" >90.4%</td>
#       <td id="T_ba982_row4_col2" class="data row4 col2" >80.7%</td>
#       <td id="T_ba982_row4_col3" class="data row4 col3" >86 672</td>
#       <td id="T_ba982_row4_col4" class="data row4 col4" >2 949</td>
#       <td id="T_ba982_row4_col5" class="data row4 col5" >3.4%</td>
#     </tr>
#     <tr>
#       <th id="T_ba982_level0_row5" class="row_heading level0 row5" >2020-06</th>
#       <td id="T_ba982_row5_col0" class="data row5 col0" >final_model_preds</td>
#       <td id="T_ba982_row5_col1" class="data row5 col1" >88.2%</td>
#       <td id="T_ba982_row5_col2" class="data row5 col2" >76.4%</td>
#       <td id="T_ba982_row5_col3" class="data row5 col3" >86 572</td>
#       <td id="T_ba982_row5_col4" class="data row5 col4" >2 995</td>
#       <td id="T_ba982_row5_col5" class="data row5 col5" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_ba982_level0_row6" class="row_heading level0 row6" >2020-07</th>
#       <td id="T_ba982_row6_col0" class="data row6 col0" >final_model_preds</td>
#       <td id="T_ba982_row6_col1" class="data row6 col1" >90.7%</td>
#       <td id="T_ba982_row6_col2" class="data row6 col2" >81.3%</td>
#       <td id="T_ba982_row6_col3" class="data row6 col3" >2 754</td>
#       <td id="T_ba982_row6_col4" class="data row6 col4" >119</td>
#       <td id="T_ba982_row6_col5" class="data row6 col5" >4.3%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Графики распределения таргета по выборкам
fig, axes = plt.subplots(1, 2, figsize=(16, 4), gridspec_kw={'width_ratios': [1, 1.7]})
masks_dict = {'TRAIN': TRAIN_MASK, 'TEST': TEST_MASK, 'OOT': OOT_MASK}

ax = axes[0]
plot_roc_by_masks(data, TARGET, 'final_model_preds', masks_dict, 
                     figsize=(8, 4), palette='bright', 
                     title='ROC-кривые по различным подвыборкам',
                     ax=ax)

ax = axes[1]
plot_gini_by_period_styled(metr_split.reset_index(), 'gini', DATE_MONTH,
                              figsize=(8, 4), 
                              target_gini=40,
                              title='Динамика Gini по периодам',
                              ax=ax)

# %% [markdown]
# # Сохранение модели

# %%
final_model.save_model(r'./models/final_model.cbm')
joblib.dump(pipeline, r'.models/pipeline.joblib')
# Out:
# ['pipeline.joblib']

# %% [markdown]
# # SHAP переменных

# %%
# Создаем explainer
explainer = shap.TreeExplainer(final_model)

# Вычисляем SHAP значения для разных выборок
shap_cb_train = explainer(
    dev_sample.loc[TRAIN_MASK, FINAL_FEATURES],
    dev_sample.loc[TRAIN_MASK, TARGET]
)

shap_cb_test = explainer(
    dev_sample.loc[TEST_MASK, FINAL_FEATURES],
    dev_sample.loc[TEST_MASK, TARGET]
)

shap_cb_oot = explainer(
    dev_sample.loc[OOT_MASK, FINAL_FEATURES],
    dev_sample.loc[OOT_MASK, TARGET]
)

# %%
# Создаем summary plot
shap.summary_plot(
    shap_cb_test,
    dev_sample.loc[TEST_MASK, FINAL_FEATURES],
    feature_names=FINAL_FEATURES,
    plot_type="dot",
    max_display=len(FINAL_FEATURES),
    plot_size=(9, 7),
    show=False
)

# Сохраняем график
# path = r"reports/plots/shap.png"
# plt.savefig(path, bbox_inches="tight", pad_inches=0.1)

# %% [markdown]
# # Выводы
#  <span style="color:orange">Собрали стабильную модель</span>
