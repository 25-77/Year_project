# %% [markdown]
# # Смена директории

# %%
# %cd ..
# Out:
# /Users/uzumnasiya/HSE/Year_Project

# %% [markdown]
# # Импорт библиотек

# %%
import logging
import warnings


import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import yaml
import joblib
import shap
import optuna
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from category_encoders import CatBoostEncoder
from catboost import CatBoostClassifier


from utils.dev_utils import get_pool
from utils.pipeline_utils import CustomPreprocessor
from utils.metrics import MetricCalculator, metric_funcs
from utils.style.styler import style_metrics
from utils.style.html_output import print_multiple_html
from utils.plot_utils import plot_gini_by_period_styled, plot_roc_by_masks

# %%
logging.getLogger().setLevel(logging.WARNING)
warnings.filterwarnings('ignore')
sns.set_palette('bright')


pd.options.display.float_format = "{:.2f}".format
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %%
# %load_ext autoreload
# %autoreload 2
# %aimport utils.plot_utils
# %aimport utils.eda_utils
# %aimport utils.style_utils
# %aimport utils.psi
# %aimport utils.style.styler

# %% [markdown]
# # Входные данные

# %% [markdown]
# ## Загрузка данных

# %%
data = pd.read_parquet('./data/processed/data.pqt')

data.shape
# Out:
# (1097231, 494)

# %% [markdown]
# ## Валидные переменные

# %%
path = r'./docs/valid_features.xlsx'
valid_features_data = pd.read_excel(path, index_col=False)

# %% [markdown]
# ## Конфиги/константы

# %%
TARGET = 'target'
DATE_MONTH = 'date_month'
DATE_QUARTAL = 'date_quartal'

FEATURES = valid_features_data.loc[(valid_features_data['valid_flag'] == 1)]['attribute'].values
CAT_FEATURES = list(set(FEATURES) & set(data.select_dtypes(include=["object", "category"]).columns))
NUM_FEATURES = list(set(FEATURES) & set(data.select_dtypes(include=["number"]).columns))

TRAIN_MASK = (data['sample_type'] == 'TRAIN')
TEST_MASK = (data['sample_type'] == 'TEST')
OOT_MASK = (data['sample_type'] == 'OOT')

DEV_MASK = (data['competition_sample_type'] == 'TRAIN')

# %%
print_multiple_html(
    ('Кол-во переменных: ', len(FEATURES)),
    ('Кол-во категориальных переменных: ', len(CAT_FEATURES))
)
# Out:
# <div style='margin-bottom: 1.4px;'>
#                 <b style='white-space: pre;'>Кол-во переменных: </b>
#                 <b style='color:orange;'>371</b>
#             </div><div style='margin-bottom: 1.4px;'>
#                 <b style='white-space: pre;'>Кол-во категориальных переменных: </b>
#                 <b style='color:orange;'>16</b>
#             </div>

# %%
metr_funcs = {
    'roc_auc': metric_funcs.roc_auc_score_nan,
    'gini': metric_funcs.gini_score_nan,
}

stats_funcs = {
    'obs_cnt': lambda y_true, data: len(y_true),
    'target_cnt': lambda y_true, data: sum(y_true),
    'DR': lambda y_true, data: sum(y_true) / len(y_true)
}

# Класс для расчета метрик
metr_calc = MetricCalculator(metr_funcs=metr_funcs, stats_funcs=stats_funcs)


STYLE_CONFIG = {
    'percent_cols': ['gini', 'roc_auc', 'DR'],
    'int_cols': ['obs_cnt', 'target_cnt'],
    'gradient_cols': ['gini', 'roc_auc'],
    'gradient_cmap': 'RdYlGn',
}

# %%
def metrics_split(data, group_cols, metr_calc, pred_cols=['lg_model_preds'], target='target', asc=True):
    """Упрощенный интерфес для расчета метрик"""

    metr_split = metr_calc.calculate(data, true_col=target, pred_cols=pred_cols, group_cols=group_cols)
    metr_split = (
        metr_split
        .sort_values(by=group_cols, ascending=asc)
        .set_index(group_cols)
    )
    
    return metr_split

# %% [markdown]
# # Обучение LogReg

# %%
default_params = {
    'penalty': 'l1',
    'dual': False,
    'tol': 0.0001,
    'C': 1.0,
    'fit_intercept': True,
    'intercept_scaling': 1,
    'solver': 'saga',
    'max_iter': 100,
    'random_state': 42,
}


preprocessor = ColumnTransformer(
    transformers=[
        ('num', Pipeline([
            ('imputer', SimpleImputer(strategy='median')),
            ('scaler', StandardScaler())
        ]), NUM_FEATURES),
        ('cat', CatBoostEncoder(), CAT_FEATURES),
    ], 
    remainder='passthrough'
)

pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('model', LogisticRegression(**default_params))
])

pipeline.fit(data.loc[TRAIN_MASK][FEATURES], data.loc[TRAIN_MASK][TARGET])
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['V284', 'V31', 'V70', 'V252',
#                                                    'V297', 'V290', 'V22',
#                                                    'V220', 'V180', 'addr1',
#                                                    'V85', 'V189', 'card3',
#                                                    'V75', 'V289', 'V21', 'V229',
#                                                    'V286', 'V195', 'V279',
#                                                    'V181', 'V274', 'V321',
#                                                    'V186', 'V91', 'V19', 'V300',
#                                                    'V327', 'V294', 'card5', ...]),
#                                                  ('cat', CatBoostEncoder(),
#                                                   ['P_emaildomain', 'M1', 'M9',
#                                                    'DeviceType', 'ProductCD',
#                                                    'M5', 'M6', 'M2',
#                                                    'R_emaildomain', 'M7',
#                                                    'card4', 'card6', 'M3', 'M4',
#                                                    'DeviceInfo', 'M8'])])),
#                 ('model',
#                  LogisticRegression(penalty='l1', random_state=42,
#                                     solver='saga'))])

# %%
data['lg_model_preds'] = pipeline.predict_proba(data[FEATURES])[:, 1]

# %%
# Выводим топ-20
model_from_pipeline = pipeline.named_steps['model']

coef_df_scaling = pd.DataFrame({
    'feature': FEATURES,
    'coef': abs(model_from_pipeline.coef_[0])
})

coef_df_scaling.sort_values(by='coef', ascending=False).head(20)
# Out:
#            feature  coef
# 368         second  0.12
# 363           V339  0.12
# 358           V334  0.12
# 215           V188  0.11
# 360           V336  0.10
# 64             V17  0.10
# 355           V331  0.10
# 12   R_emaildomain  0.10
# 365     DeviceInfo  0.09
# 359           V335  0.09
# 364     DeviceType  0.09
# 370       hour_cos  0.09
# 156           V129  0.09
# 357           V333  0.09
# 189           V162  0.09
# 366           hour  0.09
# 324           V299  0.08
# 356           V332  0.08
# 362           V338  0.08
# 274           V249  0.08

# %% [markdown]
# ## Метрики базовой модели

# %%
metr_split = metrics_split(
    data=data.loc[DEV_MASK],
    target=TARGET,
    pred_cols='lg_model_preds',
    group_cols='sample_type',
    metr_calc=metr_calc,
    asc=False
)

style_metrics(metr_split, STYLE_CONFIG)
# Out:
# <style type="text/css">
# #T_ebc36_row0_col1, #T_ebc36_row0_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_ebc36_row1_col1, #T_ebc36_row1_col2 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_ebc36_row2_col1, #T_ebc36_row2_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ebc36">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ebc36_level0_col0" class="col_heading level0 col0" >level_1</th>
#       <th id="T_ebc36_level0_col1" class="col_heading level0 col1" >roc_auc</th>
#       <th id="T_ebc36_level0_col2" class="col_heading level0 col2" >gini</th>
#       <th id="T_ebc36_level0_col3" class="col_heading level0 col3" >obs_cnt</th>
#       <th id="T_ebc36_level0_col4" class="col_heading level0 col4" >target_cnt</th>
#       <th id="T_ebc36_level0_col5" class="col_heading level0 col5" >DR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sample_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ebc36_level0_row0" class="row_heading level0 row0" >TRAIN</th>
#       <td id="T_ebc36_row0_col0" class="data row0 col0" >lg_model_preds</td>
#       <td id="T_ebc36_row0_col1" class="data row0 col1" >83.0%</td>
#       <td id="T_ebc36_row0_col2" class="data row0 col2" >66.1%</td>
#       <td id="T_ebc36_row0_col3" class="data row0 col3" >350 849</td>
#       <td id="T_ebc36_row0_col4" class="data row0 col4" >12 166</td>
#       <td id="T_ebc36_row0_col5" class="data row0 col5" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_ebc36_level0_row1" class="row_heading level0 row1" >TEST</th>
#       <td id="T_ebc36_row1_col0" class="data row1 col0" >lg_model_preds</td>
#       <td id="T_ebc36_row1_col1" class="data row1 col1" >82.8%</td>
#       <td id="T_ebc36_row1_col2" class="data row1 col2" >65.5%</td>
#       <td id="T_ebc36_row1_col3" class="data row1 col3" >150 365</td>
#       <td id="T_ebc36_row1_col4" class="data row1 col4" >5 383</td>
#       <td id="T_ebc36_row1_col5" class="data row1 col5" >3.6%</td>
#     </tr>
#     <tr>
#       <th id="T_ebc36_level0_row2" class="row_heading level0 row2" >OOT</th>
#       <td id="T_ebc36_row2_col0" class="data row2 col0" >lg_model_preds</td>
#       <td id="T_ebc36_row2_col1" class="data row2 col1" >81.1%</td>
#       <td id="T_ebc36_row2_col2" class="data row2 col2" >62.2%</td>
#       <td id="T_ebc36_row2_col3" class="data row2 col3" >89 326</td>
#       <td id="T_ebc36_row2_col4" class="data row2 col4" >3 114</td>
#       <td id="T_ebc36_row2_col5" class="data row2 col5" >3.5%</td>
#     </tr>
#   </tbody>
# </table>

# %%
metr_split = metrics_split(
    data=data.loc[DEV_MASK],
    target=TARGET,
    pred_cols='lg_model_preds',
    group_cols=DATE_MONTH,
    metr_calc=metr_calc,
    asc=True
)

style_metrics(metr_split, STYLE_CONFIG)
# Out:
# <style type="text/css">
# #T_b80c2_row0_col1, #T_b80c2_row0_col2 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_b80c2_row1_col1, #T_b80c2_row1_col2 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_b80c2_row2_col1, #T_b80c2_row2_col2 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_b80c2_row3_col1, #T_b80c2_row3_col2 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_b80c2_row4_col1, #T_b80c2_row4_col2 {
#   background-color: #e0422f;
#   color: #f1f1f1;
# }
# #T_b80c2_row5_col1, #T_b80c2_row5_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_b80c2_row6_col1, #T_b80c2_row6_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b80c2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b80c2_level0_col0" class="col_heading level0 col0" >level_1</th>
#       <th id="T_b80c2_level0_col1" class="col_heading level0 col1" >roc_auc</th>
#       <th id="T_b80c2_level0_col2" class="col_heading level0 col2" >gini</th>
#       <th id="T_b80c2_level0_col3" class="col_heading level0 col3" >obs_cnt</th>
#       <th id="T_b80c2_level0_col4" class="col_heading level0 col4" >target_cnt</th>
#       <th id="T_b80c2_level0_col5" class="col_heading level0 col5" >DR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >date_month</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b80c2_level0_row0" class="row_heading level0 row0" >2020-01</th>
#       <td id="T_b80c2_row0_col0" class="data row0 col0" >lg_model_preds</td>
#       <td id="T_b80c2_row0_col1" class="data row0 col1" >81.6%</td>
#       <td id="T_b80c2_row0_col2" class="data row0 col2" >63.3%</td>
#       <td id="T_b80c2_row0_col3" class="data row0 col3" >134 339</td>
#       <td id="T_b80c2_row0_col4" class="data row0 col4" >3 401</td>
#       <td id="T_b80c2_row0_col5" class="data row0 col5" >2.5%</td>
#     </tr>
#     <tr>
#       <th id="T_b80c2_level0_row1" class="row_heading level0 row1" >2020-02</th>
#       <td id="T_b80c2_row1_col0" class="data row1 col0" >lg_model_preds</td>
#       <td id="T_b80c2_row1_col1" class="data row1 col1" >84.5%</td>
#       <td id="T_b80c2_row1_col2" class="data row1 col2" >68.9%</td>
#       <td id="T_b80c2_row1_col3" class="data row1 col3" >86 467</td>
#       <td id="T_b80c2_row1_col4" class="data row1 col4" >3 469</td>
#       <td id="T_b80c2_row1_col5" class="data row1 col5" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_b80c2_level0_row2" class="row_heading level0 row2" >2020-03</th>
#       <td id="T_b80c2_row2_col0" class="data row2 col0" >lg_model_preds</td>
#       <td id="T_b80c2_row2_col1" class="data row2 col1" >84.1%</td>
#       <td id="T_b80c2_row2_col2" class="data row2 col2" >68.3%</td>
#       <td id="T_b80c2_row2_col3" class="data row2 col3" >95 121</td>
#       <td id="T_b80c2_row2_col4" class="data row2 col4" >3 832</td>
#       <td id="T_b80c2_row2_col5" class="data row2 col5" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_b80c2_level0_row3" class="row_heading level0 row3" >2020-04</th>
#       <td id="T_b80c2_row3_col0" class="data row3 col0" >lg_model_preds</td>
#       <td id="T_b80c2_row3_col1" class="data row3 col1" >83.3%</td>
#       <td id="T_b80c2_row3_col2" class="data row3 col2" >66.5%</td>
#       <td id="T_b80c2_row3_col3" class="data row3 col3" >98 615</td>
#       <td id="T_b80c2_row3_col4" class="data row3 col4" >3 898</td>
#       <td id="T_b80c2_row3_col5" class="data row3 col5" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_b80c2_level0_row4" class="row_heading level0 row4" >2020-05</th>
#       <td id="T_b80c2_row4_col0" class="data row4 col0" >lg_model_preds</td>
#       <td id="T_b80c2_row4_col1" class="data row4 col1" >81.6%</td>
#       <td id="T_b80c2_row4_col2" class="data row4 col2" >63.2%</td>
#       <td id="T_b80c2_row4_col3" class="data row4 col3" >86 672</td>
#       <td id="T_b80c2_row4_col4" class="data row4 col4" >2 949</td>
#       <td id="T_b80c2_row4_col5" class="data row4 col5" >3.4%</td>
#     </tr>
#     <tr>
#       <th id="T_b80c2_level0_row5" class="row_heading level0 row5" >2020-06</th>
#       <td id="T_b80c2_row5_col0" class="data row5 col0" >lg_model_preds</td>
#       <td id="T_b80c2_row5_col1" class="data row5 col1" >80.9%</td>
#       <td id="T_b80c2_row5_col2" class="data row5 col2" >61.8%</td>
#       <td id="T_b80c2_row5_col3" class="data row5 col3" >86 572</td>
#       <td id="T_b80c2_row5_col4" class="data row5 col4" >2 995</td>
#       <td id="T_b80c2_row5_col5" class="data row5 col5" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_b80c2_level0_row6" class="row_heading level0 row6" >2020-07</th>
#       <td id="T_b80c2_row6_col0" class="data row6 col0" >lg_model_preds</td>
#       <td id="T_b80c2_row6_col1" class="data row6 col1" >86.1%</td>
#       <td id="T_b80c2_row6_col2" class="data row6 col2" >72.1%</td>
#       <td id="T_b80c2_row6_col3" class="data row6 col3" >2 754</td>
#       <td id="T_b80c2_row6_col4" class="data row6 col4" >119</td>
#       <td id="T_b80c2_row6_col5" class="data row6 col5" >4.3%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Графики распределения таргета по выборкам
fig, axes = plt.subplots(1, 2, figsize=(16, 4), gridspec_kw={'width_ratios': [1, 1.7]})
masks_dict = {'TRAIN': TRAIN_MASK, 'TEST': TEST_MASK, 'OOT': OOT_MASK}

ax = axes[0]
plot_roc_by_masks(data, TARGET, 'lg_model_preds', masks_dict, 
                     figsize=(8, 4), palette='bright', 
                     title='ROC-кривые по различным подвыборкам',
                     ax=ax)

ax = axes[1]
plot_gini_by_period_styled(metr_split.reset_index(), 'gini', DATE_MONTH,
                              figsize=(8, 4), 
                              target_gini=40,
                              title='Динамика Gini по периодам',
                              ax=ax)

# %% [markdown]
# # Обучение CatBoost

# %%
# Берем только наблюдения с взаимной целевой и преобразуем кат. фичи
dev_sample = data.loc[DEV_MASK].copy()

# Трансформируем категориальные переменные
dev_sample = CustomPreprocessor(cat_features=CAT_FEATURES).transform(dev_sample)

# %%
train_pool = get_pool(dev_sample, TARGET, TRAIN_MASK, FEATURES, CAT_FEATURES)
test_pool = get_pool(dev_sample, TARGET, TEST_MASK, FEATURES, CAT_FEATURES)
oot_pool = get_pool(dev_sample, TARGET, OOT_MASK, FEATURES, CAT_FEATURES)

# %%
# Параметры модели
default_params = {
    "iterations": 100,
    "loss_function": "Logloss",
    "eval_metric": "AUC",
    "early_stopping_rounds": 20,
    "verbose": 0,
    "random_seed": 42,
}

# %%
# Обучение модели
model = CatBoostClassifier(**default_params, cat_features=CAT_FEATURES)
model.fit(train_pool, eval_set=test_pool, use_best_model=True, plot=False)

# %%
# Предсказания для всего набора
pipeline = Pipeline([
    ('preprocessor', CustomPreprocessor(cat_features=CAT_FEATURES)),
    ('model', model),
])

data['cb_model_preds'] = pipeline.predict_proba(data[FEATURES])[:, 1]

# %% [markdown]
# ## Метрики

# %%
# По сэмплам
metr_split = metrics_split(
    data=data.loc[DEV_MASK],
    target=TARGET,
    pred_cols='cb_model_preds',
    group_cols='sample_type',
    metr_calc=metr_calc,
    asc=False
)

style_metrics(metr_split, STYLE_CONFIG)
# Out:
# <style type="text/css">
# #T_cb242_row0_col1, #T_cb242_row0_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_cb242_row1_col1, #T_cb242_row1_col2 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_cb242_row2_col1, #T_cb242_row2_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cb242">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb242_level0_col0" class="col_heading level0 col0" >level_1</th>
#       <th id="T_cb242_level0_col1" class="col_heading level0 col1" >roc_auc</th>
#       <th id="T_cb242_level0_col2" class="col_heading level0 col2" >gini</th>
#       <th id="T_cb242_level0_col3" class="col_heading level0 col3" >obs_cnt</th>
#       <th id="T_cb242_level0_col4" class="col_heading level0 col4" >target_cnt</th>
#       <th id="T_cb242_level0_col5" class="col_heading level0 col5" >DR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sample_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb242_level0_row0" class="row_heading level0 row0" >TRAIN</th>
#       <td id="T_cb242_row0_col0" class="data row0 col0" >cb_model_preds</td>
#       <td id="T_cb242_row0_col1" class="data row0 col1" >91.7%</td>
#       <td id="T_cb242_row0_col2" class="data row0 col2" >83.4%</td>
#       <td id="T_cb242_row0_col3" class="data row0 col3" >350 849</td>
#       <td id="T_cb242_row0_col4" class="data row0 col4" >12 166</td>
#       <td id="T_cb242_row0_col5" class="data row0 col5" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_cb242_level0_row1" class="row_heading level0 row1" >TEST</th>
#       <td id="T_cb242_row1_col0" class="data row1 col0" >cb_model_preds</td>
#       <td id="T_cb242_row1_col1" class="data row1 col1" >90.9%</td>
#       <td id="T_cb242_row1_col2" class="data row1 col2" >81.8%</td>
#       <td id="T_cb242_row1_col3" class="data row1 col3" >150 365</td>
#       <td id="T_cb242_row1_col4" class="data row1 col4" >5 383</td>
#       <td id="T_cb242_row1_col5" class="data row1 col5" >3.6%</td>
#     </tr>
#     <tr>
#       <th id="T_cb242_level0_row2" class="row_heading level0 row2" >OOT</th>
#       <td id="T_cb242_row2_col0" class="data row2 col0" >cb_model_preds</td>
#       <td id="T_cb242_row2_col1" class="data row2 col1" >88.5%</td>
#       <td id="T_cb242_row2_col2" class="data row2 col2" >76.9%</td>
#       <td id="T_cb242_row2_col3" class="data row2 col3" >89 326</td>
#       <td id="T_cb242_row2_col4" class="data row2 col4" >3 114</td>
#       <td id="T_cb242_row2_col5" class="data row2 col5" >3.5%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# По месяцам
metr_split = metrics_split(
    data=data.loc[DEV_MASK],
    target=TARGET,
    pred_cols='cb_model_preds',
    group_cols=DATE_MONTH,
    metr_calc=metr_calc,
    asc=True
)

style_metrics(metr_split, STYLE_CONFIG)
# Out:
# <style type="text/css">
# #T_d80ea_row0_col1, #T_d80ea_row0_col2 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_d80ea_row1_col1, #T_d80ea_row1_col2 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_d80ea_row2_col1, #T_d80ea_row2_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_d80ea_row3_col1, #T_d80ea_row3_col2 {
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_d80ea_row4_col1, #T_d80ea_row4_col2 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_d80ea_row5_col1, #T_d80ea_row5_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_d80ea_row6_col1, #T_d80ea_row6_col2 {
#   background-color: #fede89;
#   color: #000000;
# }
# </style>
# <table id="T_d80ea">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d80ea_level0_col0" class="col_heading level0 col0" >level_1</th>
#       <th id="T_d80ea_level0_col1" class="col_heading level0 col1" >roc_auc</th>
#       <th id="T_d80ea_level0_col2" class="col_heading level0 col2" >gini</th>
#       <th id="T_d80ea_level0_col3" class="col_heading level0 col3" >obs_cnt</th>
#       <th id="T_d80ea_level0_col4" class="col_heading level0 col4" >target_cnt</th>
#       <th id="T_d80ea_level0_col5" class="col_heading level0 col5" >DR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >date_month</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d80ea_level0_row0" class="row_heading level0 row0" >2020-01</th>
#       <td id="T_d80ea_row0_col0" class="data row0 col0" >cb_model_preds</td>
#       <td id="T_d80ea_row0_col1" class="data row0 col1" >91.1%</td>
#       <td id="T_d80ea_row0_col2" class="data row0 col2" >82.1%</td>
#       <td id="T_d80ea_row0_col3" class="data row0 col3" >134 339</td>
#       <td id="T_d80ea_row0_col4" class="data row0 col4" >3 401</td>
#       <td id="T_d80ea_row0_col5" class="data row0 col5" >2.5%</td>
#     </tr>
#     <tr>
#       <th id="T_d80ea_level0_row1" class="row_heading level0 row1" >2020-02</th>
#       <td id="T_d80ea_row1_col0" class="data row1 col0" >cb_model_preds</td>
#       <td id="T_d80ea_row1_col1" class="data row1 col1" >91.9%</td>
#       <td id="T_d80ea_row1_col2" class="data row1 col2" >83.7%</td>
#       <td id="T_d80ea_row1_col3" class="data row1 col3" >86 467</td>
#       <td id="T_d80ea_row1_col4" class="data row1 col4" >3 469</td>
#       <td id="T_d80ea_row1_col5" class="data row1 col5" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_d80ea_level0_row2" class="row_heading level0 row2" >2020-03</th>
#       <td id="T_d80ea_row2_col0" class="data row2 col0" >cb_model_preds</td>
#       <td id="T_d80ea_row2_col1" class="data row2 col1" >92.1%</td>
#       <td id="T_d80ea_row2_col2" class="data row2 col2" >84.1%</td>
#       <td id="T_d80ea_row2_col3" class="data row2 col3" >95 121</td>
#       <td id="T_d80ea_row2_col4" class="data row2 col4" >3 832</td>
#       <td id="T_d80ea_row2_col5" class="data row2 col5" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_d80ea_level0_row3" class="row_heading level0 row3" >2020-04</th>
#       <td id="T_d80ea_row3_col0" class="data row3 col0" >cb_model_preds</td>
#       <td id="T_d80ea_row3_col1" class="data row3 col1" >91.1%</td>
#       <td id="T_d80ea_row3_col2" class="data row3 col2" >82.2%</td>
#       <td id="T_d80ea_row3_col3" class="data row3 col3" >98 615</td>
#       <td id="T_d80ea_row3_col4" class="data row3 col4" >3 898</td>
#       <td id="T_d80ea_row3_col5" class="data row3 col5" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_d80ea_level0_row4" class="row_heading level0 row4" >2020-05</th>
#       <td id="T_d80ea_row4_col0" class="data row4 col0" >cb_model_preds</td>
#       <td id="T_d80ea_row4_col1" class="data row4 col1" >91.1%</td>
#       <td id="T_d80ea_row4_col2" class="data row4 col2" >82.3%</td>
#       <td id="T_d80ea_row4_col3" class="data row4 col3" >86 672</td>
#       <td id="T_d80ea_row4_col4" class="data row4 col4" >2 949</td>
#       <td id="T_d80ea_row4_col5" class="data row4 col5" >3.4%</td>
#     </tr>
#     <tr>
#       <th id="T_d80ea_level0_row5" class="row_heading level0 row5" >2020-06</th>
#       <td id="T_d80ea_row5_col0" class="data row5 col0" >cb_model_preds</td>
#       <td id="T_d80ea_row5_col1" class="data row5 col1" >88.4%</td>
#       <td id="T_d80ea_row5_col2" class="data row5 col2" >76.8%</td>
#       <td id="T_d80ea_row5_col3" class="data row5 col3" >86 572</td>
#       <td id="T_d80ea_row5_col4" class="data row5 col4" >2 995</td>
#       <td id="T_d80ea_row5_col5" class="data row5 col5" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_d80ea_level0_row6" class="row_heading level0 row6" >2020-07</th>
#       <td id="T_d80ea_row6_col0" class="data row6 col0" >cb_model_preds</td>
#       <td id="T_d80ea_row6_col1" class="data row6 col1" >89.9%</td>
#       <td id="T_d80ea_row6_col2" class="data row6 col2" >79.7%</td>
#       <td id="T_d80ea_row6_col3" class="data row6 col3" >2 754</td>
#       <td id="T_d80ea_row6_col4" class="data row6 col4" >119</td>
#       <td id="T_d80ea_row6_col5" class="data row6 col5" >4.3%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Графики распределения таргета по выборкам
fig, axes = plt.subplots(1, 2, figsize=(16, 4), gridspec_kw={'width_ratios': [1, 1.7]})
masks_dict = {'TRAIN': TRAIN_MASK, 'TEST': TEST_MASK, 'OOT': OOT_MASK}

ax = axes[0]
plot_roc_by_masks(data, TARGET, 'lg_model_preds', masks_dict, 
                     figsize=(8, 4), palette='bright', 
                     title='ROC-кривые по различным подвыборкам',
                     ax=ax)

ax = axes[1]
plot_gini_by_period_styled(metr_split.reset_index(), 'gini', DATE_MONTH,
                              figsize=(8, 4), 
                              target_gini=40,
                              title='Динамика Gini по периодам',
                              ax=ax)

# %% [markdown]
# # Сравнение моделей

# %%
# По сэмплам для roc_auc и gini
metr_split = metrics_split(
    data=data.loc[DEV_MASK],
    target=TARGET,
    pred_cols=['cb_model_preds', 'lg_model_preds'],
    group_cols='sample_type',
    metr_calc=metr_calc,
    asc=False
)

style_metrics(metr_split.reset_index(), STYLE_CONFIG)
# Out:
# <style type="text/css">
# #T_ad0c7_row0_col2, #T_ad0c7_row0_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_ad0c7_row1_col2, #T_ad0c7_row1_col3 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_ad0c7_row2_col2, #T_ad0c7_row2_col3 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_ad0c7_row3_col2, #T_ad0c7_row3_col3 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_ad0c7_row4_col2, #T_ad0c7_row4_col3 {
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_ad0c7_row5_col2, #T_ad0c7_row5_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ad0c7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad0c7_level0_col0" class="col_heading level0 col0" >sample_type</th>
#       <th id="T_ad0c7_level0_col1" class="col_heading level0 col1" >level_1</th>
#       <th id="T_ad0c7_level0_col2" class="col_heading level0 col2" >roc_auc</th>
#       <th id="T_ad0c7_level0_col3" class="col_heading level0 col3" >gini</th>
#       <th id="T_ad0c7_level0_col4" class="col_heading level0 col4" >obs_cnt</th>
#       <th id="T_ad0c7_level0_col5" class="col_heading level0 col5" >target_cnt</th>
#       <th id="T_ad0c7_level0_col6" class="col_heading level0 col6" >DR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad0c7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ad0c7_row0_col0" class="data row0 col0" >TRAIN</td>
#       <td id="T_ad0c7_row0_col1" class="data row0 col1" >cb_model_preds</td>
#       <td id="T_ad0c7_row0_col2" class="data row0 col2" >91.7%</td>
#       <td id="T_ad0c7_row0_col3" class="data row0 col3" >83.4%</td>
#       <td id="T_ad0c7_row0_col4" class="data row0 col4" >350 849</td>
#       <td id="T_ad0c7_row0_col5" class="data row0 col5" >12 166</td>
#       <td id="T_ad0c7_row0_col6" class="data row0 col6" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_ad0c7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ad0c7_row1_col0" class="data row1 col0" >TRAIN</td>
#       <td id="T_ad0c7_row1_col1" class="data row1 col1" >lg_model_preds</td>
#       <td id="T_ad0c7_row1_col2" class="data row1 col2" >83.0%</td>
#       <td id="T_ad0c7_row1_col3" class="data row1 col3" >66.1%</td>
#       <td id="T_ad0c7_row1_col4" class="data row1 col4" >350 849</td>
#       <td id="T_ad0c7_row1_col5" class="data row1 col5" >12 166</td>
#       <td id="T_ad0c7_row1_col6" class="data row1 col6" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_ad0c7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ad0c7_row2_col0" class="data row2 col0" >TEST</td>
#       <td id="T_ad0c7_row2_col1" class="data row2 col1" >cb_model_preds</td>
#       <td id="T_ad0c7_row2_col2" class="data row2 col2" >90.9%</td>
#       <td id="T_ad0c7_row2_col3" class="data row2 col3" >81.8%</td>
#       <td id="T_ad0c7_row2_col4" class="data row2 col4" >150 365</td>
#       <td id="T_ad0c7_row2_col5" class="data row2 col5" >5 383</td>
#       <td id="T_ad0c7_row2_col6" class="data row2 col6" >3.6%</td>
#     </tr>
#     <tr>
#       <th id="T_ad0c7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ad0c7_row3_col0" class="data row3 col0" >TEST</td>
#       <td id="T_ad0c7_row3_col1" class="data row3 col1" >lg_model_preds</td>
#       <td id="T_ad0c7_row3_col2" class="data row3 col2" >82.8%</td>
#       <td id="T_ad0c7_row3_col3" class="data row3 col3" >65.5%</td>
#       <td id="T_ad0c7_row3_col4" class="data row3 col4" >150 365</td>
#       <td id="T_ad0c7_row3_col5" class="data row3 col5" >5 383</td>
#       <td id="T_ad0c7_row3_col6" class="data row3 col6" >3.6%</td>
#     </tr>
#     <tr>
#       <th id="T_ad0c7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ad0c7_row4_col0" class="data row4 col0" >OOT</td>
#       <td id="T_ad0c7_row4_col1" class="data row4 col1" >cb_model_preds</td>
#       <td id="T_ad0c7_row4_col2" class="data row4 col2" >88.5%</td>
#       <td id="T_ad0c7_row4_col3" class="data row4 col3" >76.9%</td>
#       <td id="T_ad0c7_row4_col4" class="data row4 col4" >89 326</td>
#       <td id="T_ad0c7_row4_col5" class="data row4 col5" >3 114</td>
#       <td id="T_ad0c7_row4_col6" class="data row4 col6" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_ad0c7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ad0c7_row5_col0" class="data row5 col0" >OOT</td>
#       <td id="T_ad0c7_row5_col1" class="data row5 col1" >lg_model_preds</td>
#       <td id="T_ad0c7_row5_col2" class="data row5 col2" >81.1%</td>
#       <td id="T_ad0c7_row5_col3" class="data row5 col3" >62.2%</td>
#       <td id="T_ad0c7_row5_col4" class="data row5 col4" >89 326</td>
#       <td id="T_ad0c7_row5_col5" class="data row5 col5" >3 114</td>
#       <td id="T_ad0c7_row5_col6" class="data row5 col6" >3.5%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Сравнение по Gini
metr_split_pivot = (
    metr_split.pivot(columns="level_1", values="gini")
    .add_prefix("gini_")
    .join(metr_split[["obs_cnt", "target_cnt", "DR"]])
    .drop_duplicates()
)

style_config_compare = {
    "percent_cols": ["gini_cb_model_preds", "gini_lg_model_preds", "DR"],
    "gradient_cols": ["gini_cb_model_preds", "gini_lg_model_preds"],
}

style_metrics(metr_split_pivot, {**STYLE_CONFIG, **style_config_compare}, axis=1)
# Out:
# <style type="text/css">
# #T_8662c_row0_col0, #T_8662c_row1_col0, #T_8662c_row2_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_8662c_row0_col1, #T_8662c_row1_col1, #T_8662c_row2_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8662c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8662c_level0_col0" class="col_heading level0 col0" >gini_cb_model_preds</th>
#       <th id="T_8662c_level0_col1" class="col_heading level0 col1" >gini_lg_model_preds</th>
#       <th id="T_8662c_level0_col2" class="col_heading level0 col2" >obs_cnt</th>
#       <th id="T_8662c_level0_col3" class="col_heading level0 col3" >target_cnt</th>
#       <th id="T_8662c_level0_col4" class="col_heading level0 col4" >DR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sample_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8662c_level0_row0" class="row_heading level0 row0" >OOT</th>
#       <td id="T_8662c_row0_col0" class="data row0 col0" >76.9%</td>
#       <td id="T_8662c_row0_col1" class="data row0 col1" >62.2%</td>
#       <td id="T_8662c_row0_col2" class="data row0 col2" >89 326</td>
#       <td id="T_8662c_row0_col3" class="data row0 col3" >3 114</td>
#       <td id="T_8662c_row0_col4" class="data row0 col4" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_8662c_level0_row1" class="row_heading level0 row1" >TEST</th>
#       <td id="T_8662c_row1_col0" class="data row1 col0" >81.8%</td>
#       <td id="T_8662c_row1_col1" class="data row1 col1" >65.5%</td>
#       <td id="T_8662c_row1_col2" class="data row1 col2" >150 365</td>
#       <td id="T_8662c_row1_col3" class="data row1 col3" >5 383</td>
#       <td id="T_8662c_row1_col4" class="data row1 col4" >3.6%</td>
#     </tr>
#     <tr>
#       <th id="T_8662c_level0_row2" class="row_heading level0 row2" >TRAIN</th>
#       <td id="T_8662c_row2_col0" class="data row2 col0" >83.4%</td>
#       <td id="T_8662c_row2_col1" class="data row2 col1" >66.1%</td>
#       <td id="T_8662c_row2_col2" class="data row2 col2" >350 849</td>
#       <td id="T_8662c_row2_col3" class="data row2 col3" >12 166</td>
#       <td id="T_8662c_row2_col4" class="data row2 col4" >3.5%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Отбор переменных

# %%
importances_df = pd.DataFrame({
    'Feature': model.feature_names_,
    'Importance': model.get_feature_importance()
}).sort_values('Importance', ascending=False)

importances_df.head(8)
# Out:
#             Feature  Importance
# 24              C13        5.46
# 319            V294        3.69
# 7             card6        3.57
# 13               C1        3.56
# 3             card2        3.38
# 25              C14        3.24
# 131             V91        3.22
# 0    TransactionAmt        2.89

# %%
# Далее используем важные переменные
IMP_SHORT_FEATURES = importances_df[importances_df['Importance'] > 0.01]['Feature'].to_list()
IMP_CAT_FEATURES = [i for i in CAT_FEATURES if i in IMP_SHORT_FEATURES]

print_multiple_html(
    (f"Кол-во важных фичей (total): ", len(IMP_SHORT_FEATURES)),
    (f"Кол-во важных категориальных фичей: ", len(IMP_CAT_FEATURES)),
)
# Out:
# <div style='margin-bottom: 1.4px;'>
#                 <b style='white-space: pre;'>Кол-во важных фичей (total): </b>
#                 <b style='color:orange;'>191</b>
#             </div><div style='margin-bottom: 1.4px;'>
#                 <b style='white-space: pre;'>Кол-во важных категориальных фичей: </b>
#                 <b style='color:orange;'>12</b>
#             </div>

# %%
# Для простоты берем топ-30
FINAL_FEATURES = importances_df.loc[importances_df['Feature'].isin(IMP_SHORT_FEATURES)][:30]['Feature'].to_list()
FINAL_CAT_FEATURES = [i for i in IMP_CAT_FEATURES if i in FINAL_FEATURES]

# %%
print_multiple_html(
    (f"Кол-во финальных фичей: ", len(FINAL_FEATURES)),
    (f"Кол-во финальных категориальных фичей: ", len(FINAL_CAT_FEATURES)),
)
# Out:
# <div style='margin-bottom: 1.4px;'>
#                 <b style='white-space: pre;'>Кол-во финальных фичей: </b>
#                 <b style='color:orange;'>30</b>
#             </div><div style='margin-bottom: 1.4px;'>
#                 <b style='white-space: pre;'>Кол-во финальных категориальных фичей: </b>
#                 <b style='color:orange;'>7</b>
#             </div>

# %%
# Сохраняем переменные
features = {
    'FINAL_FEATURES': FINAL_FEATURES,
    'FINAL_CAT_FEATURES': FINAL_CAT_FEATURES
}

with open(r'./models/params/features.yaml', 'w', encoding='utf-8') as file:
    yaml.dump(features, file, allow_unicode=True, default_flow_style=False)

# %% [markdown]
# # Подбор гиперпараметров

# %%
# Обновляем пулы данных
train_pool = get_pool(dev_sample, TARGET, TRAIN_MASK, FINAL_FEATURES, FINAL_CAT_FEATURES)
test_pool = get_pool(dev_sample, TARGET, TEST_MASK, FINAL_FEATURES, FINAL_CAT_FEATURES)
oot_pool = get_pool(dev_sample, TARGET, OOT_MASK, FINAL_FEATURES, FINAL_CAT_FEATURES)

# %%
def objective(trial):
    params = {
        'iterations':trial.suggest_int("iterations", 100, 500),                                # Количество деревьев в бустинге
        'depth': trial.suggest_int('depth', 4, 7),                                             # Глубина деревьев
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),            # Скорость обучения
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 0.1),              # Выборка признаков на каждом уровне дерева 
        'verbose': False,
        'random_state': 42
    }

    catboost = CatBoostClassifier(**params)
    catboost.fit(train_pool, plot=False)
    
    roc_auc = roc_auc_score(data[TEST_MASK][TARGET], catboost.predict_proba(test_pool)[:, 1])
    return roc_auc

# %%
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=10, show_progress_bar=False)
# Out:
# [I 2025-12-05 11:48:37,591] A new study created in memory with name: no-name-8d592495-ccf1-42ac-9a2f-d3178df1247b
# [I 2025-12-05 11:49:17,554] Trial 0 finished with value: 0.9048330714133531 and parameters: {'iterations': 250, 'depth': 7, 'learning_rate': 0.1205712628744377, 'colsample_bylevel': 0.0638792635777333}. Best is trial 0 with value: 0.9048330714133531.
# [I 2025-12-05 11:49:38,421] Trial 1 finished with value: 0.8392748508361533 and parameters: {'iterations': 162, 'depth': 4, 'learning_rate': 0.012184186502221764, 'colsample_bylevel': 0.08795585311974417}. Best is trial 0 with value: 0.9048330714133531.
# [I 2025-12-05 11:50:30,601] Trial 2 finished with value: 0.8683154176995044 and parameters: {'iterations': 341, 'depth': 6, 'learning_rate': 0.010725209743171997, 'colsample_bylevel': 0.0972918866945795}. Best is trial 0 with value: 0.9048330714133531.
# [I 2025-12-05 11:51:06,413] Trial 3 finished with value: 0.8428459053228239 and parameters: {'iterations': 433, 'depth': 4, 'learning_rate': 0.01855998084649058, 'colsample_bylevel': 0.026506405886809047}. Best is trial 0 with value: 0.9048330714133531.
# [I 2025-12-05 11:51:24,678] Trial 4 finished with value: 0.8660685482981786 and parameters: {'iterations': 222, 'depth': 6, 'learning_rate': 0.04345454109729477, 'colsample_bylevel': 0.036210622617823776}. Best is trial 0 with value: 0.9048330714133531.
# [I 2025-12-05 11:51:50,045] Trial 5 finished with value: 0.8633035814373728 and parameters: {'iterations': 345, 'depth': 4, 'learning_rate': 0.027010527749605478, 'colsample_bylevel': 0.04297256589643226}. Best is trial 0 with value: 0.9048330714133531.
# [I 2025-12-05 11:52:14,210] Trial 6 finished with value: 0.872303572526993 and parameters: {'iterations': 282, 'depth': 7, 'learning_rate': 0.019721610970574007, 'colsample_bylevel': 0.05628109945722505}. Best is trial 0 with value: 0.9048330714133531.
# [I 2025-12-05 11:52:35,731] Trial 7 finished with value: 0.8672237359973298 and parameters: {'iterations': 337, 'depth': 4, 'learning_rate': 0.07896186801026692, 'colsample_bylevel': 0.02534717113185624}. Best is trial 0 with value: 0.9048330714133531.
# [I 2025-12-05 11:52:46,481] Trial 8 finished with value: 0.9029926102813848 and parameters: {'iterations': 126, 'depth': 7, 'learning_rate': 0.26690431824362526, 'colsample_bylevel': 0.08275576133048151}. Best is trial 0 with value: 0.9048330714133531.
# [I 2025-12-05 11:53:02,856] Trial 9 finished with value: 0.8804729173488102 and parameters: {'iterations': 222, 'depth': 4, 'learning_rate': 0.1024932221692416, 'colsample_bylevel': 0.04961372443656412}. Best is trial 0 with value: 0.9048330714133531.

# %%
final_params = {**default_params, **study.best_params}
final_params
# Out:
# {'iterations': 250,
#  'loss_function': 'Logloss',
#  'eval_metric': 'AUC',
#  'early_stopping_rounds': 20,
#  'verbose': 0,
#  'random_seed': 42,
#  'depth': 7,
#  'learning_rate': 0.1205712628744377,
#  'colsample_bylevel': 0.0638792635777333}

# %%
# Сохраняем параметры
with open(r'./models/params/best_params.yaml', 'w', encoding='utf-8') as file:
    yaml.dump(final_params, file)

# %% [markdown]
# # Обучение финальной модели

# %%
# Создаем пулы данных
train_pool = get_pool(dev_sample, TARGET, TRAIN_MASK, FINAL_FEATURES, FINAL_CAT_FEATURES)
test_pool = get_pool(dev_sample, TARGET, TEST_MASK, FINAL_FEATURES, FINAL_CAT_FEATURES)
oot_pool = get_pool(dev_sample, TARGET, OOT_MASK, FINAL_FEATURES, FINAL_CAT_FEATURES)

# %%
# Создаем и обучаем модель
final_model = CatBoostClassifier(**final_params, cat_features=FINAL_CAT_FEATURES)
final_model.fit(train_pool, eval_set=test_pool)

# %%
# Предсказания для dev_sample
dev_sample['final_model_preds'] = final_model.predict_proba(dev_sample[FINAL_FEATURES])[:, 1]

# %%
# # Предсказания для всего набора
pipeline = Pipeline([
    ('preprocessor', CustomPreprocessor(cat_features=FINAL_CAT_FEATURES)),
    ('model', final_model),
])

data['final_model_preds'] = pipeline.predict_proba(data[FINAL_FEATURES])[:, 1]

# %% [markdown]
# ## Метрики финальной модели

# %%
# По сэмплам
metr_split = metrics_split(
    data=data.loc[DEV_MASK],
    target=TARGET,
    pred_cols='final_model_preds',
    group_cols='sample_type',
    metr_calc=metr_calc,
    asc=False
)

style_metrics(metr_split, STYLE_CONFIG)
# Out:
# <style type="text/css">
# #T_bb1fa_row0_col1, #T_bb1fa_row0_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_bb1fa_row1_col1, #T_bb1fa_row1_col2 {
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_bb1fa_row2_col1, #T_bb1fa_row2_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bb1fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb1fa_level0_col0" class="col_heading level0 col0" >level_1</th>
#       <th id="T_bb1fa_level0_col1" class="col_heading level0 col1" >roc_auc</th>
#       <th id="T_bb1fa_level0_col2" class="col_heading level0 col2" >gini</th>
#       <th id="T_bb1fa_level0_col3" class="col_heading level0 col3" >obs_cnt</th>
#       <th id="T_bb1fa_level0_col4" class="col_heading level0 col4" >target_cnt</th>
#       <th id="T_bb1fa_level0_col5" class="col_heading level0 col5" >DR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sample_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb1fa_level0_row0" class="row_heading level0 row0" >TRAIN</th>
#       <td id="T_bb1fa_row0_col0" class="data row0 col0" >final_model_preds</td>
#       <td id="T_bb1fa_row0_col1" class="data row0 col1" >91.1%</td>
#       <td id="T_bb1fa_row0_col2" class="data row0 col2" >82.1%</td>
#       <td id="T_bb1fa_row0_col3" class="data row0 col3" >350 849</td>
#       <td id="T_bb1fa_row0_col4" class="data row0 col4" >12 166</td>
#       <td id="T_bb1fa_row0_col5" class="data row0 col5" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_bb1fa_level0_row1" class="row_heading level0 row1" >TEST</th>
#       <td id="T_bb1fa_row1_col0" class="data row1 col0" >final_model_preds</td>
#       <td id="T_bb1fa_row1_col1" class="data row1 col1" >90.5%</td>
#       <td id="T_bb1fa_row1_col2" class="data row1 col2" >81.0%</td>
#       <td id="T_bb1fa_row1_col3" class="data row1 col3" >150 365</td>
#       <td id="T_bb1fa_row1_col4" class="data row1 col4" >5 383</td>
#       <td id="T_bb1fa_row1_col5" class="data row1 col5" >3.6%</td>
#     </tr>
#     <tr>
#       <th id="T_bb1fa_level0_row2" class="row_heading level0 row2" >OOT</th>
#       <td id="T_bb1fa_row2_col0" class="data row2 col0" >final_model_preds</td>
#       <td id="T_bb1fa_row2_col1" class="data row2 col1" >88.3%</td>
#       <td id="T_bb1fa_row2_col2" class="data row2 col2" >76.6%</td>
#       <td id="T_bb1fa_row2_col3" class="data row2 col3" >89 326</td>
#       <td id="T_bb1fa_row2_col4" class="data row2 col4" >3 114</td>
#       <td id="T_bb1fa_row2_col5" class="data row2 col5" >3.5%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# По месяцам
metr_split = metrics_split(
    data=data.loc[DEV_MASK],
    target=TARGET,
    pred_cols='final_model_preds',
    group_cols=DATE_MONTH,
    metr_calc=metr_calc,
    asc=True
)

style_metrics(metr_split, STYLE_CONFIG)
# Out:
# <style type="text/css">
# #T_647dc_row0_col1, #T_647dc_row0_col2 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_647dc_row1_col1, #T_647dc_row1_col2 {
#   background-color: #54b45f;
#   color: #f1f1f1;
# }
# #T_647dc_row2_col1, #T_647dc_row2_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_647dc_row3_col1, #T_647dc_row3_col2 {
#   background-color: #b5df74;
#   color: #000000;
# }
# #T_647dc_row4_col1, #T_647dc_row4_col2 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_647dc_row5_col1, #T_647dc_row5_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_647dc_row6_col1, #T_647dc_row6_col2 {
#   background-color: #afdd70;
#   color: #000000;
# }
# </style>
# <table id="T_647dc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_647dc_level0_col0" class="col_heading level0 col0" >level_1</th>
#       <th id="T_647dc_level0_col1" class="col_heading level0 col1" >roc_auc</th>
#       <th id="T_647dc_level0_col2" class="col_heading level0 col2" >gini</th>
#       <th id="T_647dc_level0_col3" class="col_heading level0 col3" >obs_cnt</th>
#       <th id="T_647dc_level0_col4" class="col_heading level0 col4" >target_cnt</th>
#       <th id="T_647dc_level0_col5" class="col_heading level0 col5" >DR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >date_month</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_647dc_level0_row0" class="row_heading level0 row0" >2020-01</th>
#       <td id="T_647dc_row0_col0" class="data row0 col0" >final_model_preds</td>
#       <td id="T_647dc_row0_col1" class="data row0 col1" >90.4%</td>
#       <td id="T_647dc_row0_col2" class="data row0 col2" >80.9%</td>
#       <td id="T_647dc_row0_col3" class="data row0 col3" >134 339</td>
#       <td id="T_647dc_row0_col4" class="data row0 col4" >3 401</td>
#       <td id="T_647dc_row0_col5" class="data row0 col5" >2.5%</td>
#     </tr>
#     <tr>
#       <th id="T_647dc_level0_row1" class="row_heading level0 row1" >2020-02</th>
#       <td id="T_647dc_row1_col0" class="data row1 col0" >final_model_preds</td>
#       <td id="T_647dc_row1_col1" class="data row1 col1" >91.2%</td>
#       <td id="T_647dc_row1_col2" class="data row1 col2" >82.3%</td>
#       <td id="T_647dc_row1_col3" class="data row1 col3" >86 467</td>
#       <td id="T_647dc_row1_col4" class="data row1 col4" >3 469</td>
#       <td id="T_647dc_row1_col5" class="data row1 col5" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_647dc_level0_row2" class="row_heading level0 row2" >2020-03</th>
#       <td id="T_647dc_row2_col0" class="data row2 col0" >final_model_preds</td>
#       <td id="T_647dc_row2_col1" class="data row2 col1" >91.8%</td>
#       <td id="T_647dc_row2_col2" class="data row2 col2" >83.6%</td>
#       <td id="T_647dc_row2_col3" class="data row2 col3" >95 121</td>
#       <td id="T_647dc_row2_col4" class="data row2 col4" >3 832</td>
#       <td id="T_647dc_row2_col5" class="data row2 col5" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_647dc_level0_row3" class="row_heading level0 row3" >2020-04</th>
#       <td id="T_647dc_row3_col0" class="data row3 col0" >final_model_preds</td>
#       <td id="T_647dc_row3_col1" class="data row3 col1" >90.6%</td>
#       <td id="T_647dc_row3_col2" class="data row3 col2" >81.2%</td>
#       <td id="T_647dc_row3_col3" class="data row3 col3" >98 615</td>
#       <td id="T_647dc_row3_col4" class="data row3 col4" >3 898</td>
#       <td id="T_647dc_row3_col5" class="data row3 col5" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_647dc_level0_row4" class="row_heading level0 row4" >2020-05</th>
#       <td id="T_647dc_row4_col0" class="data row4 col0" >final_model_preds</td>
#       <td id="T_647dc_row4_col1" class="data row4 col1" >90.4%</td>
#       <td id="T_647dc_row4_col2" class="data row4 col2" >80.7%</td>
#       <td id="T_647dc_row4_col3" class="data row4 col3" >86 672</td>
#       <td id="T_647dc_row4_col4" class="data row4 col4" >2 949</td>
#       <td id="T_647dc_row4_col5" class="data row4 col5" >3.4%</td>
#     </tr>
#     <tr>
#       <th id="T_647dc_level0_row5" class="row_heading level0 row5" >2020-06</th>
#       <td id="T_647dc_row5_col0" class="data row5 col0" >final_model_preds</td>
#       <td id="T_647dc_row5_col1" class="data row5 col1" >88.2%</td>
#       <td id="T_647dc_row5_col2" class="data row5 col2" >76.4%</td>
#       <td id="T_647dc_row5_col3" class="data row5 col3" >86 572</td>
#       <td id="T_647dc_row5_col4" class="data row5 col4" >2 995</td>
#       <td id="T_647dc_row5_col5" class="data row5 col5" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_647dc_level0_row6" class="row_heading level0 row6" >2020-07</th>
#       <td id="T_647dc_row6_col0" class="data row6 col0" >final_model_preds</td>
#       <td id="T_647dc_row6_col1" class="data row6 col1" >90.7%</td>
#       <td id="T_647dc_row6_col2" class="data row6 col2" >81.3%</td>
#       <td id="T_647dc_row6_col3" class="data row6 col3" >2 754</td>
#       <td id="T_647dc_row6_col4" class="data row6 col4" >119</td>
#       <td id="T_647dc_row6_col5" class="data row6 col5" >4.3%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Графики распределения таргета по выборкам
fig, axes = plt.subplots(1, 2, figsize=(16, 4), gridspec_kw={'width_ratios': [1, 1.7]})
masks_dict = {'TRAIN': TRAIN_MASK, 'TEST': TEST_MASK, 'OOT': OOT_MASK}

ax = axes[0]
plot_roc_by_masks(data, TARGET, 'final_model_preds', masks_dict, 
                     figsize=(8, 4), palette='bright', 
                     title='ROC-кривые по различным подвыборкам',
                     ax=ax)

ax = axes[1]
plot_gini_by_period_styled(metr_split.reset_index(), 'gini', DATE_MONTH,
                              figsize=(8, 4), 
                              target_gini=40,
                              title='Динамика Gini по периодам',
                              ax=ax)

# %% [markdown]
# # Сохранение модели

# %%
final_model.save_model(r'./models/final_model.cbm')
joblib.dump(pipeline, r'./models/pipeline.joblib')
# Out:
# ['./models/pipeline.joblib']

# %% [markdown]
# # SHAP переменных

# %%
# Создаем explainer
explainer = shap.TreeExplainer(final_model)

# Вычисляем SHAP значения для разных выборок
shap_cb_train = explainer(
    dev_sample.loc[TRAIN_MASK, FINAL_FEATURES],
    dev_sample.loc[TRAIN_MASK, TARGET]
)

shap_cb_test = explainer(
    dev_sample.loc[TEST_MASK, FINAL_FEATURES],
    dev_sample.loc[TEST_MASK, TARGET]
)

shap_cb_oot = explainer(
    dev_sample.loc[OOT_MASK, FINAL_FEATURES],
    dev_sample.loc[OOT_MASK, TARGET]
)

# %%
# Создаем summary plot
shap.summary_plot(
    shap_cb_test,
    dev_sample.loc[TEST_MASK, FINAL_FEATURES],
    feature_names=FINAL_FEATURES,
    plot_type="dot",
    max_display=len(FINAL_FEATURES),
    plot_size=(9, 7),
    show=False
)

# Сохраняем график
# path = r"reports/plots/shap.png"
# plt.savefig(path, bbox_inches="tight", pad_inches=0.1)
