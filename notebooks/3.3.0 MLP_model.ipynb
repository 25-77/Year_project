# %% [markdown]
# # Смена директории

# %%
# %cd ..
# Out:
# /Users/macbook/Desktop/Project/Year_project

# %% [markdown]
# # Импорт библиотек

# %%
import logging
import warnings
import time


import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import yaml
import joblib
import shap
import optuna
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.utils.class_weight import compute_class_weight
from sklearn.neural_network import MLPClassifier
from category_encoders import CatBoostEncoder
from tensorflow.keras.models import Sequential # type: ignore
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization # type: ignore
from tensorflow.keras.metrics import AUC # type: ignore
from tensorflow.keras.callbacks import EarlyStopping # type: ignore


from utils.dev_utils import get_pool
from utils.pipeline_utils import CustomPreprocessor
from utils.metrics import MetricCalculator, metric_funcs
from utils.style.styler import style_metrics
from utils.style.html_output import print_multiple_html
from utils.plot_utils import plot_gini_by_period_styled, plot_roc_by_masks

# %%
logging.getLogger().setLevel(logging.WARNING)
warnings.filterwarnings('ignore')
sns.set_palette('bright')


pd.options.display.float_format = "{:.2f}".format
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %%
# %load_ext autoreload
# %autoreload 2
# %aimport utils.plot_utils
# %aimport utils.eda_utils
# %aimport utils.style_utils
# %aimport utils.psi
# %aimport utils.style.styler

# %% [markdown]
# # Входные данные

# %% [markdown]
# ## Загрузка данных

# %%
data = pd.read_parquet('./data/processed/data.pqt')

data.shape
# Out:
# (1097231, 633)

# %% [markdown]
# ## Валидные переменные

# %%
path = r'./docs/valid_features.xlsx'
valid_features_data = pd.read_excel(path, index_col=False)

# %% [markdown]
# ## Конфиги/константы

# %%
TARGET = 'target'
DATE_MONTH = 'date_month'
DATE_QUARTAL = 'date_quartal'

FEATURES = valid_features_data.loc[(
    valid_features_data['valid_flag'] == 1)]['attribute'].values
CAT_FEATURES = sorted(set(FEATURES) & set(
    data.select_dtypes(include=["object", "category"]).columns))
NUM_FEATURES = sorted(set(FEATURES) & set(
    data.select_dtypes(include=["number"]).columns))

TRAIN_MASK = (data['sample_type'] == 'TRAIN')
TEST_MASK = (data['sample_type'] == 'TEST')
OOT_MASK = (data['sample_type'] == 'OOT')

DEV_MASK = (data['competition_sample_type'] == 'TRAIN')

# %%
print_multiple_html(
    ('Кол-во переменных: ', len(FEATURES)),
    ('Кол-во категориальных переменных: ', len(CAT_FEATURES))
)
# Out:
# <div style='margin-bottom: 1.4px;'>
#                 <b style='white-space: pre;'>Кол-во переменных: </b>
#                 <b style='color:orange;'>481</b>
#             </div><div style='margin-bottom: 1.4px;'>
#                 <b style='white-space: pre;'>Кол-во категориальных переменных: </b>
#                 <b style='color:orange;'>39</b>
#             </div>

# %%
metr_funcs = {
    'roc_auc': metric_funcs.roc_auc_score_nan,
    'gini': metric_funcs.gini_score_nan,
    'precision': metric_funcs.precision,
    'recall': metric_funcs.recall
}

stats_funcs = {
    'obs_cnt': lambda y_true, data: len(y_true),
    'target_cnt': lambda y_true, data: sum(y_true),
    'DR': lambda y_true, data: sum(y_true) / len(y_true)
}

# Класс для расчета метрик
metr_calc = MetricCalculator(metr_funcs=metr_funcs, stats_funcs=stats_funcs)


STYLE_CONFIG = {
    'percent_cols': ['gini', 'roc_auc', 'DR', 'precision', 'recall'],
    'int_cols': ['obs_cnt', 'target_cnt'],
    'gradient_cols': ['gini', 'roc_auc', 'precision', 'recall'],
    'gradient_cmap': 'RdYlGn',
}

# %%
def metrics_split(data, group_cols, metr_calc, pred_cols=['lg_model_preds'], target='target', asc=True):
    """Упрощенный интерфес для расчета метрик"""

    metr_split = metr_calc.calculate(
        data, true_col=target, pred_cols=pred_cols, group_cols=group_cols)
    metr_split = (
        metr_split
        .sort_values(by=group_cols, ascending=asc)
        .set_index(group_cols)
    )

    return metr_split

# %% [markdown]
# # Обучение MLPClassifier из sklearn

# %%
default_params = {"hidden_layer_sizes": (100, 50),
                  'activation': 'relu',
                  'alpha': 0.001,
                  'random_state': 42,
                  'max_iter': 500,
                  'early_stopping': True,
                  }

preprocessor = ColumnTransformer(
    transformers=[
        ('num', Pipeline([
            ('imputer', SimpleImputer(strategy='median')),
            ('scaler', StandardScaler())
        ]), NUM_FEATURES),
        ('cat', CatBoostEncoder(CatBoostEncoder(sigma=0.1, a=1
                                                )), CAT_FEATURES),
    ],
    remainder='passthrough'
)

pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('model', MLPClassifier(**default_params))
])

pipeline.fit(data.loc[TRAIN_MASK][FEATURES], data.loc[TRAIN_MASK][TARGET])
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['C1', 'C10', 'C11', 'C12',
#                                                    'C13', 'C14', 'C2', 'C4',
#                                                    'C5', 'C6', 'C7', 'C8', 'C9',
#                                                    'D1', 'D10', 'D11', 'D12',
#                                                    'D13', 'D14', 'D15', 'D2',
#                                                    'D3', 'D4', 'D5', 'D6', 'D7',
#                                                    'D8', 'D9', 'Transaction...
#                                                    'M3', 'M3_new', 'M4',
#                                                    'M4_new', 'M5', 'M5_new',
#                                                    'M6', 'M6_new', 'M7',
#                                                    'M7_new', 'M8', 'M8_new',
#                                                    'M9', 'M9_new',
#                                                    'P_emaildomain',
#                                                    'P_emaildomain_grouped',
#                                                    'P_emaildomain_new',
#                                                    'ProductCD', 'ProductCD_new',
#                                                    'R_emaildomain',
#                                                    'R_emaildomain_grouped', ...])])),
#                 ('model',
#                  MLPClassifier(alpha=0.001, early_stopping=True,
#                                hidden_layer_sizes=(100, 50), max_iter=500,
#                                random_state=42))])

# %%
data['mlp_sklearn_preds'] = pipeline.predict_proba(data[FEATURES])[:, 1]

# %%
metr_split = metrics_split(
    data=data.loc[DEV_MASK],
    target=TARGET,
    pred_cols='mlp_sklearn_preds',
    group_cols='sample_type',
    metr_calc=metr_calc,
    asc=False
)

style_metrics(metr_split, STYLE_CONFIG)
# Out:
# <style type="text/css">
# #T_54815_row0_col1, #T_54815_row0_col2, #T_54815_row0_col3, #T_54815_row0_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_54815_row1_col1, #T_54815_row1_col2 {
#   background-color: #b3df72;
#   color: #000000;
# }
# #T_54815_row1_col3 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_54815_row1_col4 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_54815_row2_col1, #T_54815_row2_col2, #T_54815_row2_col3, #T_54815_row2_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_54815">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54815_level0_col0" class="col_heading level0 col0" >level_1</th>
#       <th id="T_54815_level0_col1" class="col_heading level0 col1" >roc_auc</th>
#       <th id="T_54815_level0_col2" class="col_heading level0 col2" >gini</th>
#       <th id="T_54815_level0_col3" class="col_heading level0 col3" >precision</th>
#       <th id="T_54815_level0_col4" class="col_heading level0 col4" >recall</th>
#       <th id="T_54815_level0_col5" class="col_heading level0 col5" >obs_cnt</th>
#       <th id="T_54815_level0_col6" class="col_heading level0 col6" >target_cnt</th>
#       <th id="T_54815_level0_col7" class="col_heading level0 col7" >DR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sample_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54815_level0_row0" class="row_heading level0 row0" >TRAIN</th>
#       <td id="T_54815_row0_col0" class="data row0 col0" >mlp_sklearn_preds</td>
#       <td id="T_54815_row0_col1" class="data row0 col1" >97.1%</td>
#       <td id="T_54815_row0_col2" class="data row0 col2" >94.2%</td>
#       <td id="T_54815_row0_col3" class="data row0 col3" >92.7%</td>
#       <td id="T_54815_row0_col4" class="data row0 col4" >66.4%</td>
#       <td id="T_54815_row0_col5" class="data row0 col5" >350 849</td>
#       <td id="T_54815_row0_col6" class="data row0 col6" >12 276</td>
#       <td id="T_54815_row0_col7" class="data row0 col7" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_54815_level0_row1" class="row_heading level0 row1" >TEST</th>
#       <td id="T_54815_row1_col0" class="data row1 col0" >mlp_sklearn_preds</td>
#       <td id="T_54815_row1_col1" class="data row1 col1" >93.0%</td>
#       <td id="T_54815_row1_col2" class="data row1 col2" >86.0%</td>
#       <td id="T_54815_row1_col3" class="data row1 col3" >85.3%</td>
#       <td id="T_54815_row1_col4" class="data row1 col4" >56.6%</td>
#       <td id="T_54815_row1_col5" class="data row1 col5" >150 365</td>
#       <td id="T_54815_row1_col6" class="data row1 col6" >5 273</td>
#       <td id="T_54815_row1_col7" class="data row1 col7" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_54815_level0_row2" class="row_heading level0 row2" >OOT</th>
#       <td id="T_54815_row2_col0" class="data row2 col0" >mlp_sklearn_preds</td>
#       <td id="T_54815_row2_col1" class="data row2 col1" >84.5%</td>
#       <td id="T_54815_row2_col2" class="data row2 col2" >69.1%</td>
#       <td id="T_54815_row2_col3" class="data row2 col3" >68.6%</td>
#       <td id="T_54815_row2_col4" class="data row2 col4" >40.2%</td>
#       <td id="T_54815_row2_col5" class="data row2 col5" >89 326</td>
#       <td id="T_54815_row2_col6" class="data row2 col6" >3 114</td>
#       <td id="T_54815_row2_col7" class="data row2 col7" >3.5%</td>
#     </tr>
#   </tbody>
# </table>

# %%
metr_split = metrics_split(
    data=data.loc[DEV_MASK],
    target=TARGET,
    pred_cols='mlp_sklearn_preds',
    group_cols=DATE_MONTH,
    metr_calc=metr_calc,
    asc=True
)

style_metrics(metr_split, STYLE_CONFIG)
# Out:
# <style type="text/css">
# #T_64d83_row0_col1, #T_64d83_row0_col2 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_64d83_row0_col3 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_64d83_row0_col4 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_64d83_row1_col1, #T_64d83_row1_col2 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_64d83_row1_col3 {
#   background-color: #33a456;
#   color: #f1f1f1;
# }
# #T_64d83_row1_col4 {
#   background-color: #51b35e;
#   color: #f1f1f1;
# }
# #T_64d83_row2_col1, #T_64d83_row2_col2, #T_64d83_row2_col4, #T_64d83_row3_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_64d83_row2_col3 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_64d83_row3_col1, #T_64d83_row3_col2 {
#   background-color: #0b7d42;
#   color: #f1f1f1;
# }
# #T_64d83_row3_col4 {
#   background-color: #6bbf64;
#   color: #000000;
# }
# #T_64d83_row4_col1, #T_64d83_row4_col2 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_64d83_row4_col3 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_64d83_row4_col4 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_64d83_row5_col1, #T_64d83_row5_col2 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_64d83_row5_col3, #T_64d83_row5_col4, #T_64d83_row6_col1, #T_64d83_row6_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_64d83_row6_col3 {
#   background-color: #f99355;
#   color: #000000;
# }
# #T_64d83_row6_col4 {
#   background-color: #d42d27;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_64d83">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64d83_level0_col0" class="col_heading level0 col0" >level_1</th>
#       <th id="T_64d83_level0_col1" class="col_heading level0 col1" >roc_auc</th>
#       <th id="T_64d83_level0_col2" class="col_heading level0 col2" >gini</th>
#       <th id="T_64d83_level0_col3" class="col_heading level0 col3" >precision</th>
#       <th id="T_64d83_level0_col4" class="col_heading level0 col4" >recall</th>
#       <th id="T_64d83_level0_col5" class="col_heading level0 col5" >obs_cnt</th>
#       <th id="T_64d83_level0_col6" class="col_heading level0 col6" >target_cnt</th>
#       <th id="T_64d83_level0_col7" class="col_heading level0 col7" >DR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >date_month</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64d83_level0_row0" class="row_heading level0 row0" >2020-01</th>
#       <td id="T_64d83_row0_col0" class="data row0 col0" >mlp_sklearn_preds</td>
#       <td id="T_64d83_row0_col1" class="data row0 col1" >94.5%</td>
#       <td id="T_64d83_row0_col2" class="data row0 col2" >89.0%</td>
#       <td id="T_64d83_row0_col3" class="data row0 col3" >84.4%</td>
#       <td id="T_64d83_row0_col4" class="data row0 col4" >57.2%</td>
#       <td id="T_64d83_row0_col5" class="data row0 col5" >134 339</td>
#       <td id="T_64d83_row0_col6" class="data row0 col6" >3 401</td>
#       <td id="T_64d83_row0_col7" class="data row0 col7" >2.5%</td>
#     </tr>
#     <tr>
#       <th id="T_64d83_level0_row1" class="row_heading level0 row1" >2020-02</th>
#       <td id="T_64d83_row1_col0" class="data row1 col0" >mlp_sklearn_preds</td>
#       <td id="T_64d83_row1_col1" class="data row1 col1" >95.9%</td>
#       <td id="T_64d83_row1_col2" class="data row1 col2" >91.7%</td>
#       <td id="T_64d83_row1_col3" class="data row1 col3" >90.5%</td>
#       <td id="T_64d83_row1_col4" class="data row1 col4" >63.8%</td>
#       <td id="T_64d83_row1_col5" class="data row1 col5" >86 467</td>
#       <td id="T_64d83_row1_col6" class="data row1 col6" >3 469</td>
#       <td id="T_64d83_row1_col7" class="data row1 col7" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_64d83_level0_row2" class="row_heading level0 row2" >2020-03</th>
#       <td id="T_64d83_row2_col0" class="data row2 col0" >mlp_sklearn_preds</td>
#       <td id="T_64d83_row2_col1" class="data row2 col1" >96.6%</td>
#       <td id="T_64d83_row2_col2" class="data row2 col2" >93.2%</td>
#       <td id="T_64d83_row2_col3" class="data row2 col3" >92.1%</td>
#       <td id="T_64d83_row2_col4" class="data row2 col4" >68.7%</td>
#       <td id="T_64d83_row2_col5" class="data row2 col5" >95 121</td>
#       <td id="T_64d83_row2_col6" class="data row2 col6" >3 832</td>
#       <td id="T_64d83_row2_col7" class="data row2 col7" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_64d83_level0_row3" class="row_heading level0 row3" >2020-04</th>
#       <td id="T_64d83_row3_col0" class="data row3 col0" >mlp_sklearn_preds</td>
#       <td id="T_64d83_row3_col1" class="data row3 col1" >96.0%</td>
#       <td id="T_64d83_row3_col2" class="data row3 col2" >92.0%</td>
#       <td id="T_64d83_row3_col3" class="data row3 col3" >94.0%</td>
#       <td id="T_64d83_row3_col4" class="data row3 col4" >62.7%</td>
#       <td id="T_64d83_row3_col5" class="data row3 col5" >98 615</td>
#       <td id="T_64d83_row3_col6" class="data row3 col6" >3 898</td>
#       <td id="T_64d83_row3_col7" class="data row3 col7" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_64d83_level0_row4" class="row_heading level0 row4" >2020-05</th>
#       <td id="T_64d83_row4_col0" class="data row4 col0" >mlp_sklearn_preds</td>
#       <td id="T_64d83_row4_col1" class="data row4 col1" >96.3%</td>
#       <td id="T_64d83_row4_col2" class="data row4 col2" >92.6%</td>
#       <td id="T_64d83_row4_col3" class="data row4 col3" >91.3%</td>
#       <td id="T_64d83_row4_col4" class="data row4 col4" >64.3%</td>
#       <td id="T_64d83_row4_col5" class="data row4 col5" >86 672</td>
#       <td id="T_64d83_row4_col6" class="data row4 col6" >2 949</td>
#       <td id="T_64d83_row4_col7" class="data row4 col7" >3.4%</td>
#     </tr>
#     <tr>
#       <th id="T_64d83_level0_row5" class="row_heading level0 row5" >2020-06</th>
#       <td id="T_64d83_row5_col0" class="data row5 col0" >mlp_sklearn_preds</td>
#       <td id="T_64d83_row5_col1" class="data row5 col1" >84.5%</td>
#       <td id="T_64d83_row5_col2" class="data row5 col2" >69.1%</td>
#       <td id="T_64d83_row5_col3" class="data row5 col3" >68.3%</td>
#       <td id="T_64d83_row5_col4" class="data row5 col4" >40.1%</td>
#       <td id="T_64d83_row5_col5" class="data row5 col5" >86 572</td>
#       <td id="T_64d83_row5_col6" class="data row5 col6" >2 995</td>
#       <td id="T_64d83_row5_col7" class="data row5 col7" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_64d83_level0_row6" class="row_heading level0 row6" >2020-07</th>
#       <td id="T_64d83_row6_col0" class="data row6 col0" >mlp_sklearn_preds</td>
#       <td id="T_64d83_row6_col1" class="data row6 col1" >84.4%</td>
#       <td id="T_64d83_row6_col2" class="data row6 col2" >68.8%</td>
#       <td id="T_64d83_row6_col3" class="data row6 col3" >75.0%</td>
#       <td id="T_64d83_row6_col4" class="data row6 col4" >42.9%</td>
#       <td id="T_64d83_row6_col5" class="data row6 col5" >2 754</td>
#       <td id="T_64d83_row6_col6" class="data row6 col6" >119</td>
#       <td id="T_64d83_row6_col7" class="data row6 col7" >4.3%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Графики распределения таргета по выборкам
fig, axes = plt.subplots(1, 2, figsize=(16, 4), gridspec_kw={
                         'width_ratios': [1, 1.7]})
masks_dict = {'TRAIN': TRAIN_MASK, 'TEST': TEST_MASK, 'OOT': OOT_MASK}

ax = axes[0]
plot_roc_by_masks(data, TARGET, 'mlp_sklearn_preds', masks_dict,
                  figsize=(8, 4), palette='bright',
                  title='ROC-кривые по различным подвыборкам',
                  ax=ax)

ax = axes[1]
plot_gini_by_period_styled(metr_split.reset_index(), 'gini', DATE_MONTH,
                           figsize=(8, 4),
                           target_gini=40,
                           title='Динамика Gini по периодам',
                           ax=ax)

# %% [markdown]
# # Custom MLP

# %% [markdown]
# ## Custom MLP. Model 1

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', Pipeline([
            ('imputer', SimpleImputer(strategy='median')),
            ('scaler', StandardScaler())
        ]), NUM_FEATURES),
        ('cat', CatBoostEncoder(CatBoostEncoder(sigma=0.1, a=1)
                                ), CAT_FEATURES),
    ],
    remainder='passthrough'
)

X_train_processed = preprocessor.fit_transform(
    data.loc[TRAIN_MASK][FEATURES], data.loc[TRAIN_MASK][TARGET])
X_test_processed = preprocessor.transform(data.loc[TEST_MASK][FEATURES])
X_oot_processed = preprocessor.transform(data.loc[OOT_MASK][FEATURES])

# %%
model1 = Sequential()
model1.add(Dense(512, activation='relu',
           input_shape=(X_train_processed.shape[1],)))
model1.add(Dropout(0.2, seed=42))
model1.add(Dense(128, activation='relu'))
model1.add(Dropout(0.2, seed=42))
model1.add(Dense(10, activation='tanh'))
model1.add(Dense(1, activation='sigmoid'))
model1.summary()
model1.compile(optimizer='rmsprop',
               loss='binary_crossentropy',
               metrics=[AUC()])
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_16 (Dense)                │ (None, 512)            │       246,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 10)             │         1,290 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 313,749 (1.20 MB)
#  Trainable params: 313,749 (1.20 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
class_weights = compute_class_weight('balanced', classes=np.unique(
    data.loc[TRAIN_MASK][TARGET]), y=data.loc[TRAIN_MASK][TARGET])
class_weight_dict = {0: class_weights[0], 1: class_weights[1]}

# %%
model1.fit(X_train_processed, data.loc[TRAIN_MASK][TARGET],
           batch_size=500,
           epochs=50,
           callbacks=[EarlyStopping(
               patience=5, restore_best_weights=True)],
           verbose=0)

# %%
data.loc[TRAIN_MASK, "mlp_custom1_preds"] = model1.predict(
    X_train_processed).flatten()
data.loc[TEST_MASK, "mlp_custom1_preds"] = model1.predict(
    X_test_processed).flatten()
data.loc[OOT_MASK, "mlp_custom1_preds"] = model1.predict(
    X_oot_processed).flatten()
# Out:
# 10965/10965 ━━━━━━━━━━━━━━━━━━━━ 4s 334us/step
# 4699/4699 ━━━━━━━━━━━━━━━━━━━━ 2s 334us/step
# 2792/2792 ━━━━━━━━━━━━━━━━━━━━ 1s 390us/step

# %%
metr_split = metrics_split(
    data=data.loc[DEV_MASK],
    target=TARGET,
    pred_cols='mlp_custom1_preds',
    group_cols='sample_type',
    metr_calc=metr_calc,
    asc=False
)

style_metrics(metr_split, STYLE_CONFIG)
# Out:
# <style type="text/css">
# #T_60111_row0_col1, #T_60111_row0_col2, #T_60111_row0_col3, #T_60111_row0_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_60111_row1_col1, #T_60111_row1_col2 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_60111_row1_col3 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_60111_row1_col4 {
#   background-color: #b5df74;
#   color: #000000;
# }
# #T_60111_row2_col1, #T_60111_row2_col2, #T_60111_row2_col3, #T_60111_row2_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_60111">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_60111_level0_col0" class="col_heading level0 col0" >level_1</th>
#       <th id="T_60111_level0_col1" class="col_heading level0 col1" >roc_auc</th>
#       <th id="T_60111_level0_col2" class="col_heading level0 col2" >gini</th>
#       <th id="T_60111_level0_col3" class="col_heading level0 col3" >precision</th>
#       <th id="T_60111_level0_col4" class="col_heading level0 col4" >recall</th>
#       <th id="T_60111_level0_col5" class="col_heading level0 col5" >obs_cnt</th>
#       <th id="T_60111_level0_col6" class="col_heading level0 col6" >target_cnt</th>
#       <th id="T_60111_level0_col7" class="col_heading level0 col7" >DR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sample_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60111_level0_row0" class="row_heading level0 row0" >TRAIN</th>
#       <td id="T_60111_row0_col0" class="data row0 col0" >mlp_custom1_preds</td>
#       <td id="T_60111_row0_col1" class="data row0 col1" >89.9%</td>
#       <td id="T_60111_row0_col2" class="data row0 col2" >79.7%</td>
#       <td id="T_60111_row0_col3" class="data row0 col3" >93.5%</td>
#       <td id="T_60111_row0_col4" class="data row0 col4" >62.7%</td>
#       <td id="T_60111_row0_col5" class="data row0 col5" >350 849</td>
#       <td id="T_60111_row0_col6" class="data row0 col6" >12 276</td>
#       <td id="T_60111_row0_col7" class="data row0 col7" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_60111_level0_row1" class="row_heading level0 row1" >TEST</th>
#       <td id="T_60111_row1_col0" class="data row1 col0" >mlp_custom1_preds</td>
#       <td id="T_60111_row1_col1" class="data row1 col1" >88.3%</td>
#       <td id="T_60111_row1_col2" class="data row1 col2" >76.5%</td>
#       <td id="T_60111_row1_col3" class="data row1 col3" >82.4%</td>
#       <td id="T_60111_row1_col4" class="data row1 col4" >54.7%</td>
#       <td id="T_60111_row1_col5" class="data row1 col5" >150 365</td>
#       <td id="T_60111_row1_col6" class="data row1 col6" >5 273</td>
#       <td id="T_60111_row1_col7" class="data row1 col7" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_60111_level0_row2" class="row_heading level0 row2" >OOT</th>
#       <td id="T_60111_row2_col0" class="data row2 col0" >mlp_custom1_preds</td>
#       <td id="T_60111_row2_col1" class="data row2 col1" >79.6%</td>
#       <td id="T_60111_row2_col2" class="data row2 col2" >59.3%</td>
#       <td id="T_60111_row2_col3" class="data row2 col3" >65.3%</td>
#       <td id="T_60111_row2_col4" class="data row2 col4" >38.4%</td>
#       <td id="T_60111_row2_col5" class="data row2 col5" >89 326</td>
#       <td id="T_60111_row2_col6" class="data row2 col6" >3 114</td>
#       <td id="T_60111_row2_col7" class="data row2 col7" >3.5%</td>
#     </tr>
#   </tbody>
# </table>

# %%
metr_split = metrics_split(
    data=data.loc[DEV_MASK],
    target=TARGET,
    pred_cols='mlp_custom1_preds',
    group_cols=DATE_MONTH,
    metr_calc=metr_calc,
    asc=True
)

style_metrics(metr_split, STYLE_CONFIG)
# Out:
# <style type="text/css">
# #T_4d981_row0_col1, #T_4d981_row0_col2 {
#   background-color: #b3df72;
#   color: #000000;
# }
# #T_4d981_row0_col3, #T_4d981_row4_col1, #T_4d981_row4_col2 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_4d981_row0_col4 {
#   background-color: #c7e77f;
#   color: #000000;
# }
# #T_4d981_row1_col1, #T_4d981_row1_col2 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_4d981_row1_col3 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_4d981_row1_col4 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_4d981_row2_col1, #T_4d981_row2_col2, #T_4d981_row2_col3, #T_4d981_row2_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_4d981_row3_col1, #T_4d981_row3_col2 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_4d981_row3_col3 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_4d981_row3_col4 {
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_4d981_row4_col3 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_4d981_row4_col4 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_4d981_row5_col1, #T_4d981_row5_col2, #T_4d981_row5_col4, #T_4d981_row6_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_4d981_row5_col3 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_4d981_row6_col1, #T_4d981_row6_col2 {
#   background-color: #dc3b2c;
#   color: #f1f1f1;
# }
# #T_4d981_row6_col4 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4d981">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4d981_level0_col0" class="col_heading level0 col0" >level_1</th>
#       <th id="T_4d981_level0_col1" class="col_heading level0 col1" >roc_auc</th>
#       <th id="T_4d981_level0_col2" class="col_heading level0 col2" >gini</th>
#       <th id="T_4d981_level0_col3" class="col_heading level0 col3" >precision</th>
#       <th id="T_4d981_level0_col4" class="col_heading level0 col4" >recall</th>
#       <th id="T_4d981_level0_col5" class="col_heading level0 col5" >obs_cnt</th>
#       <th id="T_4d981_level0_col6" class="col_heading level0 col6" >target_cnt</th>
#       <th id="T_4d981_level0_col7" class="col_heading level0 col7" >DR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >date_month</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d981_level0_row0" class="row_heading level0 row0" >2020-01</th>
#       <td id="T_4d981_row0_col0" class="data row0 col0" >mlp_custom1_preds</td>
#       <td id="T_4d981_row0_col1" class="data row0 col1" >87.1%</td>
#       <td id="T_4d981_row0_col2" class="data row0 col2" >74.2%</td>
#       <td id="T_4d981_row0_col3" class="data row0 col3" >86.7%</td>
#       <td id="T_4d981_row0_col4" class="data row0 col4" >55.8%</td>
#       <td id="T_4d981_row0_col5" class="data row0 col5" >134 339</td>
#       <td id="T_4d981_row0_col6" class="data row0 col6" >3 401</td>
#       <td id="T_4d981_row0_col7" class="data row0 col7" >2.5%</td>
#     </tr>
#     <tr>
#       <th id="T_4d981_level0_row1" class="row_heading level0 row1" >2020-02</th>
#       <td id="T_4d981_row1_col0" class="data row1 col0" >mlp_custom1_preds</td>
#       <td id="T_4d981_row1_col1" class="data row1 col1" >89.9%</td>
#       <td id="T_4d981_row1_col2" class="data row1 col2" >79.8%</td>
#       <td id="T_4d981_row1_col3" class="data row1 col3" >91.2%</td>
#       <td id="T_4d981_row1_col4" class="data row1 col4" >61.1%</td>
#       <td id="T_4d981_row1_col5" class="data row1 col5" >86 467</td>
#       <td id="T_4d981_row1_col6" class="data row1 col6" >3 469</td>
#       <td id="T_4d981_row1_col7" class="data row1 col7" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_4d981_level0_row2" class="row_heading level0 row2" >2020-03</th>
#       <td id="T_4d981_row2_col0" class="data row2 col0" >mlp_custom1_preds</td>
#       <td id="T_4d981_row2_col1" class="data row2 col1" >90.8%</td>
#       <td id="T_4d981_row2_col2" class="data row2 col2" >81.5%</td>
#       <td id="T_4d981_row2_col3" class="data row2 col3" >91.8%</td>
#       <td id="T_4d981_row2_col4" class="data row2 col4" >65.8%</td>
#       <td id="T_4d981_row2_col5" class="data row2 col5" >95 121</td>
#       <td id="T_4d981_row2_col6" class="data row2 col6" >3 832</td>
#       <td id="T_4d981_row2_col7" class="data row2 col7" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_4d981_level0_row3" class="row_heading level0 row3" >2020-04</th>
#       <td id="T_4d981_row3_col0" class="data row3 col0" >mlp_custom1_preds</td>
#       <td id="T_4d981_row3_col1" class="data row3 col1" >89.8%</td>
#       <td id="T_4d981_row3_col2" class="data row3 col2" >79.7%</td>
#       <td id="T_4d981_row3_col3" class="data row3 col3" >91.4%</td>
#       <td id="T_4d981_row3_col4" class="data row3 col4" >59.4%</td>
#       <td id="T_4d981_row3_col5" class="data row3 col5" >98 615</td>
#       <td id="T_4d981_row3_col6" class="data row3 col6" >3 898</td>
#       <td id="T_4d981_row3_col7" class="data row3 col7" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_4d981_level0_row4" class="row_heading level0 row4" >2020-05</th>
#       <td id="T_4d981_row4_col0" class="data row4 col0" >mlp_custom1_preds</td>
#       <td id="T_4d981_row4_col1" class="data row4 col1" >89.0%</td>
#       <td id="T_4d981_row4_col2" class="data row4 col2" >78.0%</td>
#       <td id="T_4d981_row4_col3" class="data row4 col3" >89.3%</td>
#       <td id="T_4d981_row4_col4" class="data row4 col4" >58.6%</td>
#       <td id="T_4d981_row4_col5" class="data row4 col5" >86 672</td>
#       <td id="T_4d981_row4_col6" class="data row4 col6" >2 949</td>
#       <td id="T_4d981_row4_col7" class="data row4 col7" >3.4%</td>
#     </tr>
#     <tr>
#       <th id="T_4d981_level0_row5" class="row_heading level0 row5" >2020-06</th>
#       <td id="T_4d981_row5_col0" class="data row5 col0" >mlp_custom1_preds</td>
#       <td id="T_4d981_row5_col1" class="data row5 col1" >79.6%</td>
#       <td id="T_4d981_row5_col2" class="data row5 col2" >59.2%</td>
#       <td id="T_4d981_row5_col3" class="data row5 col3" >65.5%</td>
#       <td id="T_4d981_row5_col4" class="data row5 col4" >38.4%</td>
#       <td id="T_4d981_row5_col5" class="data row5 col5" >86 572</td>
#       <td id="T_4d981_row5_col6" class="data row5 col6" >2 995</td>
#       <td id="T_4d981_row5_col7" class="data row5 col7" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_4d981_level0_row6" class="row_heading level0 row6" >2020-07</th>
#       <td id="T_4d981_row6_col0" class="data row6 col0" >mlp_custom1_preds</td>
#       <td id="T_4d981_row6_col1" class="data row6 col1" >80.9%</td>
#       <td id="T_4d981_row6_col2" class="data row6 col2" >61.8%</td>
#       <td id="T_4d981_row6_col3" class="data row6 col3" >59.7%</td>
#       <td id="T_4d981_row6_col4" class="data row6 col4" >38.7%</td>
#       <td id="T_4d981_row6_col5" class="data row6 col5" >2 754</td>
#       <td id="T_4d981_row6_col6" class="data row6 col6" >119</td>
#       <td id="T_4d981_row6_col7" class="data row6 col7" >4.3%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Графики распределения таргета по выборкам
fig, axes = plt.subplots(1, 2, figsize=(16, 4), gridspec_kw={
                         'width_ratios': [1, 1.7]})
masks_dict = {'TRAIN': TRAIN_MASK, 'TEST': TEST_MASK, 'OOT': OOT_MASK}

ax = axes[0]
plot_roc_by_masks(data, TARGET, 'mlp_custom1_preds', masks_dict,
                  figsize=(8, 4), palette='bright',
                  title='ROC-кривые по различным подвыборкам',
                  ax=ax)

ax = axes[1]
plot_gini_by_period_styled(metr_split.reset_index(), 'gini', DATE_MONTH,
                           figsize=(8, 4),
                           target_gini=40,
                           title='Динамика Gini по периодам',
                           ax=ax)

# %% [markdown]
# ## Custom MLP. Model 2

# %%
model2 = Sequential()
model2.add(Dense(128, activation='relu',
           input_shape=(X_train_processed.shape[1],)))
model2.add(BatchNormalization())
model2.add(Dropout(0.3, seed=42))
model2.add(Dense(64, activation='relu'))
model2.add(Dropout(0.2, seed=42))
model2.add(Dense(1, activation='sigmoid'))
model2.summary()
model2.compile(optimizer='rmsprop',
               loss='binary_crossentropy',
               metrics=[AUC()])
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_20 (Dense)                │ (None, 128)            │        61,696 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 70,529 (275.50 KB)
#  Trainable params: 70,273 (274.50 KB)
#  Non-trainable params: 256 (1.00 KB)

# %%
model2.fit(X_train_processed, data.loc[TRAIN_MASK][TARGET],
           batch_size=500,
           epochs=50,
           verbose=0)

data.loc[TRAIN_MASK, "mlp_custom2_preds"] = model2.predict(
    X_train_processed).flatten()
data.loc[TEST_MASK, "mlp_custom2_preds"] = model2.predict(
    X_test_processed).flatten()
data.loc[OOT_MASK, "mlp_custom2_preds"] = model2.predict(
    X_oot_processed).flatten()
# Out:
# 10965/10965 ━━━━━━━━━━━━━━━━━━━━ 3s 235us/step
# 4699/4699 ━━━━━━━━━━━━━━━━━━━━ 1s 203us/step
# 2792/2792 ━━━━━━━━━━━━━━━━━━━━ 1s 208us/step

# %%
metr_split = metrics_split(
    data=data.loc[DEV_MASK],
    target=TARGET,
    pred_cols='mlp_custom2_preds',
    group_cols='sample_type',
    metr_calc=metr_calc,
    asc=False
)

style_metrics(metr_split, STYLE_CONFIG)
# Out:
# <style type="text/css">
# #T_f56fd_row0_col1, #T_f56fd_row0_col2, #T_f56fd_row0_col3, #T_f56fd_row0_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_f56fd_row1_col1, #T_f56fd_row1_col2 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_f56fd_row1_col3 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_f56fd_row1_col4 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_f56fd_row2_col1, #T_f56fd_row2_col2, #T_f56fd_row2_col3, #T_f56fd_row2_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f56fd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f56fd_level0_col0" class="col_heading level0 col0" >level_1</th>
#       <th id="T_f56fd_level0_col1" class="col_heading level0 col1" >roc_auc</th>
#       <th id="T_f56fd_level0_col2" class="col_heading level0 col2" >gini</th>
#       <th id="T_f56fd_level0_col3" class="col_heading level0 col3" >precision</th>
#       <th id="T_f56fd_level0_col4" class="col_heading level0 col4" >recall</th>
#       <th id="T_f56fd_level0_col5" class="col_heading level0 col5" >obs_cnt</th>
#       <th id="T_f56fd_level0_col6" class="col_heading level0 col6" >target_cnt</th>
#       <th id="T_f56fd_level0_col7" class="col_heading level0 col7" >DR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sample_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f56fd_level0_row0" class="row_heading level0 row0" >TRAIN</th>
#       <td id="T_f56fd_row0_col0" class="data row0 col0" >mlp_custom2_preds</td>
#       <td id="T_f56fd_row0_col1" class="data row0 col1" >95.6%</td>
#       <td id="T_f56fd_row0_col2" class="data row0 col2" >91.3%</td>
#       <td id="T_f56fd_row0_col3" class="data row0 col3" >96.6%</td>
#       <td id="T_f56fd_row0_col4" class="data row0 col4" >58.0%</td>
#       <td id="T_f56fd_row0_col5" class="data row0 col5" >350 849</td>
#       <td id="T_f56fd_row0_col6" class="data row0 col6" >12 276</td>
#       <td id="T_f56fd_row0_col7" class="data row0 col7" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_f56fd_level0_row1" class="row_heading level0 row1" >TEST</th>
#       <td id="T_f56fd_row1_col0" class="data row1 col0" >mlp_custom2_preds</td>
#       <td id="T_f56fd_row1_col1" class="data row1 col1" >93.3%</td>
#       <td id="T_f56fd_row1_col2" class="data row1 col2" >86.6%</td>
#       <td id="T_f56fd_row1_col3" class="data row1 col3" >90.6%</td>
#       <td id="T_f56fd_row1_col4" class="data row1 col4" >52.4%</td>
#       <td id="T_f56fd_row1_col5" class="data row1 col5" >150 365</td>
#       <td id="T_f56fd_row1_col6" class="data row1 col6" >5 273</td>
#       <td id="T_f56fd_row1_col7" class="data row1 col7" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_f56fd_level0_row2" class="row_heading level0 row2" >OOT</th>
#       <td id="T_f56fd_row2_col0" class="data row2 col0" >mlp_custom2_preds</td>
#       <td id="T_f56fd_row2_col1" class="data row2 col1" >87.5%</td>
#       <td id="T_f56fd_row2_col2" class="data row2 col2" >74.9%</td>
#       <td id="T_f56fd_row2_col3" class="data row2 col3" >78.0%</td>
#       <td id="T_f56fd_row2_col4" class="data row2 col4" >37.5%</td>
#       <td id="T_f56fd_row2_col5" class="data row2 col5" >89 326</td>
#       <td id="T_f56fd_row2_col6" class="data row2 col6" >3 114</td>
#       <td id="T_f56fd_row2_col7" class="data row2 col7" >3.5%</td>
#     </tr>
#   </tbody>
# </table>

# %%
metr_split = metrics_split(
    data=data.loc[DEV_MASK],
    target=TARGET,
    pred_cols='mlp_custom2_preds',
    group_cols=DATE_MONTH,
    metr_calc=metr_calc,
    asc=True
)

style_metrics(metr_split, STYLE_CONFIG)
# Out:
# <style type="text/css">
# #T_dd64b_row0_col1, #T_dd64b_row0_col2 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_dd64b_row0_col3 {
#   background-color: #5ab760;
#   color: #f1f1f1;
# }
# #T_dd64b_row0_col4 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_dd64b_row1_col1, #T_dd64b_row1_col2 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_dd64b_row1_col3 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_dd64b_row1_col4 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_dd64b_row2_col1, #T_dd64b_row2_col2, #T_dd64b_row2_col3, #T_dd64b_row2_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_dd64b_row3_col1, #T_dd64b_row3_col2 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_dd64b_row3_col3 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_dd64b_row3_col4 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_dd64b_row4_col1, #T_dd64b_row4_col2 {
#   background-color: #0b7d42;
#   color: #f1f1f1;
# }
# #T_dd64b_row4_col3 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_dd64b_row4_col4 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# #T_dd64b_row5_col1, #T_dd64b_row5_col2 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_dd64b_row5_col3, #T_dd64b_row6_col1, #T_dd64b_row6_col2, #T_dd64b_row6_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_dd64b_row5_col4 {
#   background-color: #b10b26;
#   color: #f1f1f1;
# }
# #T_dd64b_row6_col3 {
#   background-color: #fba35c;
#   color: #000000;
# }
# </style>
# <table id="T_dd64b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd64b_level0_col0" class="col_heading level0 col0" >level_1</th>
#       <th id="T_dd64b_level0_col1" class="col_heading level0 col1" >roc_auc</th>
#       <th id="T_dd64b_level0_col2" class="col_heading level0 col2" >gini</th>
#       <th id="T_dd64b_level0_col3" class="col_heading level0 col3" >precision</th>
#       <th id="T_dd64b_level0_col4" class="col_heading level0 col4" >recall</th>
#       <th id="T_dd64b_level0_col5" class="col_heading level0 col5" >obs_cnt</th>
#       <th id="T_dd64b_level0_col6" class="col_heading level0 col6" >target_cnt</th>
#       <th id="T_dd64b_level0_col7" class="col_heading level0 col7" >DR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >date_month</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd64b_level0_row0" class="row_heading level0 row0" >2020-01</th>
#       <td id="T_dd64b_row0_col0" class="data row0 col0" >mlp_custom2_preds</td>
#       <td id="T_dd64b_row0_col1" class="data row0 col1" >93.7%</td>
#       <td id="T_dd64b_row0_col2" class="data row0 col2" >87.3%</td>
#       <td id="T_dd64b_row0_col3" class="data row0 col3" >92.7%</td>
#       <td id="T_dd64b_row0_col4" class="data row0 col4" >51.8%</td>
#       <td id="T_dd64b_row0_col5" class="data row0 col5" >134 339</td>
#       <td id="T_dd64b_row0_col6" class="data row0 col6" >3 401</td>
#       <td id="T_dd64b_row0_col7" class="data row0 col7" >2.5%</td>
#     </tr>
#     <tr>
#       <th id="T_dd64b_level0_row1" class="row_heading level0 row1" >2020-02</th>
#       <td id="T_dd64b_row1_col0" class="data row1 col0" >mlp_custom2_preds</td>
#       <td id="T_dd64b_row1_col1" class="data row1 col1" >95.1%</td>
#       <td id="T_dd64b_row1_col2" class="data row1 col2" >90.1%</td>
#       <td id="T_dd64b_row1_col3" class="data row1 col3" >95.5%</td>
#       <td id="T_dd64b_row1_col4" class="data row1 col4" >56.5%</td>
#       <td id="T_dd64b_row1_col5" class="data row1 col5" >86 467</td>
#       <td id="T_dd64b_row1_col6" class="data row1 col6" >3 469</td>
#       <td id="T_dd64b_row1_col7" class="data row1 col7" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_dd64b_level0_row2" class="row_heading level0 row2" >2020-03</th>
#       <td id="T_dd64b_row2_col0" class="data row2 col0" >mlp_custom2_preds</td>
#       <td id="T_dd64b_row2_col1" class="data row2 col1" >95.6%</td>
#       <td id="T_dd64b_row2_col2" class="data row2 col2" >91.2%</td>
#       <td id="T_dd64b_row2_col3" class="data row2 col3" >96.1%</td>
#       <td id="T_dd64b_row2_col4" class="data row2 col4" >61.1%</td>
#       <td id="T_dd64b_row2_col5" class="data row2 col5" >95 121</td>
#       <td id="T_dd64b_row2_col6" class="data row2 col6" >3 832</td>
#       <td id="T_dd64b_row2_col7" class="data row2 col7" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_dd64b_level0_row3" class="row_heading level0 row3" >2020-04</th>
#       <td id="T_dd64b_row3_col0" class="data row3 col0" >mlp_custom2_preds</td>
#       <td id="T_dd64b_row3_col1" class="data row3 col1" >95.0%</td>
#       <td id="T_dd64b_row3_col2" class="data row3 col2" >90.0%</td>
#       <td id="T_dd64b_row3_col3" class="data row3 col3" >95.2%</td>
#       <td id="T_dd64b_row3_col4" class="data row3 col4" >54.9%</td>
#       <td id="T_dd64b_row3_col5" class="data row3 col5" >98 615</td>
#       <td id="T_dd64b_row3_col6" class="data row3 col6" >3 898</td>
#       <td id="T_dd64b_row3_col7" class="data row3 col7" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_dd64b_level0_row4" class="row_heading level0 row4" >2020-05</th>
#       <td id="T_dd64b_row4_col0" class="data row4 col0" >mlp_custom2_preds</td>
#       <td id="T_dd64b_row4_col1" class="data row4 col1" >95.2%</td>
#       <td id="T_dd64b_row4_col2" class="data row4 col2" >90.5%</td>
#       <td id="T_dd64b_row4_col3" class="data row4 col3" >94.0%</td>
#       <td id="T_dd64b_row4_col4" class="data row4 col4" >56.8%</td>
#       <td id="T_dd64b_row4_col5" class="data row4 col5" >86 672</td>
#       <td id="T_dd64b_row4_col6" class="data row4 col6" >2 949</td>
#       <td id="T_dd64b_row4_col7" class="data row4 col7" >3.4%</td>
#     </tr>
#     <tr>
#       <th id="T_dd64b_level0_row5" class="row_heading level0 row5" >2020-06</th>
#       <td id="T_dd64b_row5_col0" class="data row5 col0" >mlp_custom2_preds</td>
#       <td id="T_dd64b_row5_col1" class="data row5 col1" >87.5%</td>
#       <td id="T_dd64b_row5_col2" class="data row5 col2" >74.9%</td>
#       <td id="T_dd64b_row5_col3" class="data row5 col3" >77.9%</td>
#       <td id="T_dd64b_row5_col4" class="data row5 col4" >37.6%</td>
#       <td id="T_dd64b_row5_col5" class="data row5 col5" >86 572</td>
#       <td id="T_dd64b_row5_col6" class="data row5 col6" >2 995</td>
#       <td id="T_dd64b_row5_col7" class="data row5 col7" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_dd64b_level0_row6" class="row_heading level0 row6" >2020-07</th>
#       <td id="T_dd64b_row6_col0" class="data row6 col0" >mlp_custom2_preds</td>
#       <td id="T_dd64b_row6_col1" class="data row6 col1" >87.3%</td>
#       <td id="T_dd64b_row6_col2" class="data row6 col2" >74.7%</td>
#       <td id="T_dd64b_row6_col3" class="data row6 col3" >83.0%</td>
#       <td id="T_dd64b_row6_col4" class="data row6 col4" >37.0%</td>
#       <td id="T_dd64b_row6_col5" class="data row6 col5" >2 754</td>
#       <td id="T_dd64b_row6_col6" class="data row6 col6" >119</td>
#       <td id="T_dd64b_row6_col7" class="data row6 col7" >4.3%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Графики распределения таргета по выборкам
fig, axes = plt.subplots(1, 2, figsize=(16, 4), gridspec_kw={
                         'width_ratios': [1, 1.7]})
masks_dict = {'TRAIN': TRAIN_MASK, 'TEST': TEST_MASK, 'OOT': OOT_MASK}

ax = axes[0]
plot_roc_by_masks(data, TARGET, 'mlp_custom2_preds', masks_dict,
                  figsize=(8, 4), palette='bright',
                  title='ROC-кривые по различным подвыборкам',
                  ax=ax)

ax = axes[1]
plot_gini_by_period_styled(metr_split.reset_index(), 'gini', DATE_MONTH,
                           figsize=(8, 4),
                           target_gini=40,
                           title='Динамика Gini по периодам',
                           ax=ax)

# %% [markdown]
# ## Custom MLP. Model 3

# %%
model3 = Sequential()
model3.add(Dense(512, activation='relu',
           input_shape=(X_train_processed.shape[1],)))
model3.add(BatchNormalization())
model3.add(Dropout(0.2, seed=42))
model3.add(Dense(128, activation='relu'))
model3.add(Dropout(0.2, seed=42))
model3.add(Dense(64, activation='relu'))
model3.add(Dropout(0.2, seed=42))
model3.add(Dense(1, activation='sigmoid'))
model3.summary()
model3.compile(optimizer='rmsprop',
               loss='binary_crossentropy',
               metrics=[AUC()])
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_23 (Dense)                │ (None, 512)            │       246,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 322,817 (1.23 MB)
#  Trainable params: 321,793 (1.23 MB)
#  Non-trainable params: 1,024 (4.00 KB)

# %%
model3.fit(X_train_processed, data.loc[TRAIN_MASK][TARGET],
           batch_size=500,
           epochs=50,
           verbose=0)

data.loc[TRAIN_MASK, "mlp_custom3_preds"] = model3.predict(
    X_train_processed).flatten()
data.loc[TEST_MASK, "mlp_custom3_preds"] = model3.predict(
    X_test_processed).flatten()
data.loc[OOT_MASK, "mlp_custom3_preds"] = model3.predict(
    X_oot_processed).flatten()
# Out:
# 10965/10965 ━━━━━━━━━━━━━━━━━━━━ 4s 339us/step
# 4699/4699 ━━━━━━━━━━━━━━━━━━━━ 2s 340us/step
# 2792/2792 ━━━━━━━━━━━━━━━━━━━━ 1s 334us/step

# %%
metr_split = metrics_split(
    data=data.loc[DEV_MASK],
    target=TARGET,
    pred_cols='mlp_custom3_preds',
    group_cols='sample_type',
    metr_calc=metr_calc,
    asc=False
)

style_metrics(metr_split, STYLE_CONFIG)
# Out:
# <style type="text/css">
# #T_bcb54_row0_col1, #T_bcb54_row0_col2, #T_bcb54_row0_col3, #T_bcb54_row0_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_bcb54_row1_col1, #T_bcb54_row1_col2 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_bcb54_row1_col3 {
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_bcb54_row1_col4 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_bcb54_row2_col1, #T_bcb54_row2_col2, #T_bcb54_row2_col3, #T_bcb54_row2_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bcb54">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bcb54_level0_col0" class="col_heading level0 col0" >level_1</th>
#       <th id="T_bcb54_level0_col1" class="col_heading level0 col1" >roc_auc</th>
#       <th id="T_bcb54_level0_col2" class="col_heading level0 col2" >gini</th>
#       <th id="T_bcb54_level0_col3" class="col_heading level0 col3" >precision</th>
#       <th id="T_bcb54_level0_col4" class="col_heading level0 col4" >recall</th>
#       <th id="T_bcb54_level0_col5" class="col_heading level0 col5" >obs_cnt</th>
#       <th id="T_bcb54_level0_col6" class="col_heading level0 col6" >target_cnt</th>
#       <th id="T_bcb54_level0_col7" class="col_heading level0 col7" >DR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sample_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bcb54_level0_row0" class="row_heading level0 row0" >TRAIN</th>
#       <td id="T_bcb54_row0_col0" class="data row0 col0" >mlp_custom3_preds</td>
#       <td id="T_bcb54_row0_col1" class="data row0 col1" >98.5%</td>
#       <td id="T_bcb54_row0_col2" class="data row0 col2" >97.1%</td>
#       <td id="T_bcb54_row0_col3" class="data row0 col3" >98.5%</td>
#       <td id="T_bcb54_row0_col4" class="data row0 col4" >71.0%</td>
#       <td id="T_bcb54_row0_col5" class="data row0 col5" >350 849</td>
#       <td id="T_bcb54_row0_col6" class="data row0 col6" >12 276</td>
#       <td id="T_bcb54_row0_col7" class="data row0 col7" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_bcb54_level0_row1" class="row_heading level0 row1" >TEST</th>
#       <td id="T_bcb54_row1_col0" class="data row1 col0" >mlp_custom3_preds</td>
#       <td id="T_bcb54_row1_col1" class="data row1 col1" >93.5%</td>
#       <td id="T_bcb54_row1_col2" class="data row1 col2" >87.0%</td>
#       <td id="T_bcb54_row1_col3" class="data row1 col3" >88.6%</td>
#       <td id="T_bcb54_row1_col4" class="data row1 col4" >58.7%</td>
#       <td id="T_bcb54_row1_col5" class="data row1 col5" >150 365</td>
#       <td id="T_bcb54_row1_col6" class="data row1 col6" >5 273</td>
#       <td id="T_bcb54_row1_col7" class="data row1 col7" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_bcb54_level0_row2" class="row_heading level0 row2" >OOT</th>
#       <td id="T_bcb54_row2_col0" class="data row2 col0" >mlp_custom3_preds</td>
#       <td id="T_bcb54_row2_col1" class="data row2 col1" >86.0%</td>
#       <td id="T_bcb54_row2_col2" class="data row2 col2" >72.0%</td>
#       <td id="T_bcb54_row2_col3" class="data row2 col3" >72.3%</td>
#       <td id="T_bcb54_row2_col4" class="data row2 col4" >39.9%</td>
#       <td id="T_bcb54_row2_col5" class="data row2 col5" >89 326</td>
#       <td id="T_bcb54_row2_col6" class="data row2 col6" >3 114</td>
#       <td id="T_bcb54_row2_col7" class="data row2 col7" >3.5%</td>
#     </tr>
#   </tbody>
# </table>

# %%
metr_split = metrics_split(
    data=data.loc[DEV_MASK],
    target=TARGET,
    pred_cols='mlp_custom3_preds',
    group_cols=DATE_MONTH,
    metr_calc=metr_calc,
    asc=True
)

style_metrics(metr_split, STYLE_CONFIG)
# Out:
# <style type="text/css">
# #T_b78fc_row0_col1, #T_b78fc_row0_col2 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_b78fc_row0_col3 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_b78fc_row0_col4 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_b78fc_row1_col1, #T_b78fc_row1_col2 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_b78fc_row1_col3 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_b78fc_row1_col4 {
#   background-color: #30a356;
#   color: #f1f1f1;
# }
# #T_b78fc_row2_col1, #T_b78fc_row2_col2 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_b78fc_row2_col3, #T_b78fc_row2_col4, #T_b78fc_row4_col1, #T_b78fc_row4_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_b78fc_row3_col1, #T_b78fc_row3_col2 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_b78fc_row3_col3 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_b78fc_row3_col4 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_b78fc_row4_col3 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_b78fc_row4_col4 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_b78fc_row5_col1, #T_b78fc_row5_col2 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_b78fc_row5_col3, #T_b78fc_row5_col4, #T_b78fc_row6_col1, #T_b78fc_row6_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_b78fc_row6_col3 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_b78fc_row6_col4 {
#   background-color: #de402e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b78fc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b78fc_level0_col0" class="col_heading level0 col0" >level_1</th>
#       <th id="T_b78fc_level0_col1" class="col_heading level0 col1" >roc_auc</th>
#       <th id="T_b78fc_level0_col2" class="col_heading level0 col2" >gini</th>
#       <th id="T_b78fc_level0_col3" class="col_heading level0 col3" >precision</th>
#       <th id="T_b78fc_level0_col4" class="col_heading level0 col4" >recall</th>
#       <th id="T_b78fc_level0_col5" class="col_heading level0 col5" >obs_cnt</th>
#       <th id="T_b78fc_level0_col6" class="col_heading level0 col6" >target_cnt</th>
#       <th id="T_b78fc_level0_col7" class="col_heading level0 col7" >DR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >date_month</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b78fc_level0_row0" class="row_heading level0 row0" >2020-01</th>
#       <td id="T_b78fc_row0_col0" class="data row0 col0" >mlp_custom3_preds</td>
#       <td id="T_b78fc_row0_col1" class="data row0 col1" >96.1%</td>
#       <td id="T_b78fc_row0_col2" class="data row0 col2" >92.2%</td>
#       <td id="T_b78fc_row0_col3" class="data row0 col3" >93.5%</td>
#       <td id="T_b78fc_row0_col4" class="data row0 col4" >62.8%</td>
#       <td id="T_b78fc_row0_col5" class="data row0 col5" >134 339</td>
#       <td id="T_b78fc_row0_col6" class="data row0 col6" >3 401</td>
#       <td id="T_b78fc_row0_col7" class="data row0 col7" >2.5%</td>
#     </tr>
#     <tr>
#       <th id="T_b78fc_level0_row1" class="row_heading level0 row1" >2020-02</th>
#       <td id="T_b78fc_row1_col0" class="data row1 col0" >mlp_custom3_preds</td>
#       <td id="T_b78fc_row1_col1" class="data row1 col1" >96.9%</td>
#       <td id="T_b78fc_row1_col2" class="data row1 col2" >93.9%</td>
#       <td id="T_b78fc_row1_col3" class="data row1 col3" >96.0%</td>
#       <td id="T_b78fc_row1_col4" class="data row1 col4" >67.2%</td>
#       <td id="T_b78fc_row1_col5" class="data row1 col5" >86 467</td>
#       <td id="T_b78fc_row1_col6" class="data row1 col6" >3 469</td>
#       <td id="T_b78fc_row1_col7" class="data row1 col7" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_b78fc_level0_row2" class="row_heading level0 row2" >2020-03</th>
#       <td id="T_b78fc_row2_col0" class="data row2 col0" >mlp_custom3_preds</td>
#       <td id="T_b78fc_row2_col1" class="data row2 col1" >97.4%</td>
#       <td id="T_b78fc_row2_col2" class="data row2 col2" >94.8%</td>
#       <td id="T_b78fc_row2_col3" class="data row2 col3" >97.3%</td>
#       <td id="T_b78fc_row2_col4" class="data row2 col4" >71.3%</td>
#       <td id="T_b78fc_row2_col5" class="data row2 col5" >95 121</td>
#       <td id="T_b78fc_row2_col6" class="data row2 col6" >3 832</td>
#       <td id="T_b78fc_row2_col7" class="data row2 col7" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_b78fc_level0_row3" class="row_heading level0 row3" >2020-04</th>
#       <td id="T_b78fc_row3_col0" class="data row3 col0" >mlp_custom3_preds</td>
#       <td id="T_b78fc_row3_col1" class="data row3 col1" >97.2%</td>
#       <td id="T_b78fc_row3_col2" class="data row3 col2" >94.4%</td>
#       <td id="T_b78fc_row3_col3" class="data row3 col3" >95.8%</td>
#       <td id="T_b78fc_row3_col4" class="data row3 col4" >66.7%</td>
#       <td id="T_b78fc_row3_col5" class="data row3 col5" >98 615</td>
#       <td id="T_b78fc_row3_col6" class="data row3 col6" >3 898</td>
#       <td id="T_b78fc_row3_col7" class="data row3 col7" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_b78fc_level0_row4" class="row_heading level0 row4" >2020-05</th>
#       <td id="T_b78fc_row4_col0" class="data row4 col0" >mlp_custom3_preds</td>
#       <td id="T_b78fc_row4_col1" class="data row4 col1" >97.6%</td>
#       <td id="T_b78fc_row4_col2" class="data row4 col2" >95.2%</td>
#       <td id="T_b78fc_row4_col3" class="data row4 col3" >95.4%</td>
#       <td id="T_b78fc_row4_col4" class="data row4 col4" >68.1%</td>
#       <td id="T_b78fc_row4_col5" class="data row4 col5" >86 672</td>
#       <td id="T_b78fc_row4_col6" class="data row4 col6" >2 949</td>
#       <td id="T_b78fc_row4_col7" class="data row4 col7" >3.4%</td>
#     </tr>
#     <tr>
#       <th id="T_b78fc_level0_row5" class="row_heading level0 row5" >2020-06</th>
#       <td id="T_b78fc_row5_col0" class="data row5 col0" >mlp_custom3_preds</td>
#       <td id="T_b78fc_row5_col1" class="data row5 col1" >86.0%</td>
#       <td id="T_b78fc_row5_col2" class="data row5 col2" >72.0%</td>
#       <td id="T_b78fc_row5_col3" class="data row5 col3" >72.3%</td>
#       <td id="T_b78fc_row5_col4" class="data row5 col4" >39.7%</td>
#       <td id="T_b78fc_row5_col5" class="data row5 col5" >86 572</td>
#       <td id="T_b78fc_row5_col6" class="data row5 col6" >2 995</td>
#       <td id="T_b78fc_row5_col7" class="data row5 col7" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_b78fc_level0_row6" class="row_heading level0 row6" >2020-07</th>
#       <td id="T_b78fc_row6_col0" class="data row6 col0" >mlp_custom3_preds</td>
#       <td id="T_b78fc_row6_col1" class="data row6 col1" >85.8%</td>
#       <td id="T_b78fc_row6_col2" class="data row6 col2" >71.6%</td>
#       <td id="T_b78fc_row6_col3" class="data row6 col3" >73.2%</td>
#       <td id="T_b78fc_row6_col4" class="data row6 col4" >43.7%</td>
#       <td id="T_b78fc_row6_col5" class="data row6 col5" >2 754</td>
#       <td id="T_b78fc_row6_col6" class="data row6 col6" >119</td>
#       <td id="T_b78fc_row6_col7" class="data row6 col7" >4.3%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Графики распределения таргета по выборкам
fig, axes = plt.subplots(1, 2, figsize=(16, 4), gridspec_kw={
                         'width_ratios': [1, 1.7]})
masks_dict = {'TRAIN': TRAIN_MASK, 'TEST': TEST_MASK, 'OOT': OOT_MASK}

ax = axes[0]
plot_roc_by_masks(data, TARGET, 'mlp_custom3_preds', masks_dict,
                  figsize=(8, 4), palette='bright',
                  title='ROC-кривые по различным подвыборкам',
                  ax=ax)

ax = axes[1]
plot_gini_by_period_styled(metr_split.reset_index(), 'gini', DATE_MONTH,
                           figsize=(8, 4),
                           target_gini=40,
                           title='Динамика Gini по периодам',
                           ax=ax)

# %% [markdown]
# ## Сравнение одной таблицей по ROC-AUC score

# %%
metr_funcs = {
    'roc_auc': roc_auc_score,
}
rocauc_metr_calc = MetricCalculator(metr_funcs=metr_funcs)

# %%
metr_split = metrics_split(
    data=data.loc[DEV_MASK],
    target=TARGET,
    pred_cols=['mlp_sklearn_preds', 'mlp_custom1_preds',
               'mlp_custom2_preds', 'mlp_custom3_preds'],
    group_cols='sample_type',
    metr_calc=rocauc_metr_calc,
    asc=False
)

(metr_split
    .pivot_table(index='level_1',
                 columns=metr_split.index,
                 values='roc_auc')[['TRAIN', 'TEST', 'OOT']]
    .style
    .format("{:.1%}")
    .background_gradient(cmap='RdYlGn', axis=None)
 )
# Out:
# <style type="text/css">
# #T_8cbcc_row0_col0 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_8cbcc_row0_col1 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_8cbcc_row0_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_8cbcc_row1_col0 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_8cbcc_row1_col1 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_8cbcc_row1_col2 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_8cbcc_row2_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_8cbcc_row2_col1 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_8cbcc_row2_col2 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_8cbcc_row3_col0 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_8cbcc_row3_col1 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_8cbcc_row3_col2 {
#   background-color: #f99355;
#   color: #000000;
# }
# </style>
# <table id="T_8cbcc">
#   <thead>
#     <tr>
#       <th class="index_name level0" >sample_type</th>
#       <th id="T_8cbcc_level0_col0" class="col_heading level0 col0" >TRAIN</th>
#       <th id="T_8cbcc_level0_col1" class="col_heading level0 col1" >TEST</th>
#       <th id="T_8cbcc_level0_col2" class="col_heading level0 col2" >OOT</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >level_1</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8cbcc_level0_row0" class="row_heading level0 row0" >mlp_custom1_preds</th>
#       <td id="T_8cbcc_row0_col0" class="data row0 col0" >89.9%</td>
#       <td id="T_8cbcc_row0_col1" class="data row0 col1" >88.3%</td>
#       <td id="T_8cbcc_row0_col2" class="data row0 col2" >79.6%</td>
#     </tr>
#     <tr>
#       <th id="T_8cbcc_level0_row1" class="row_heading level0 row1" >mlp_custom2_preds</th>
#       <td id="T_8cbcc_row1_col0" class="data row1 col0" >95.6%</td>
#       <td id="T_8cbcc_row1_col1" class="data row1 col1" >93.3%</td>
#       <td id="T_8cbcc_row1_col2" class="data row1 col2" >87.5%</td>
#     </tr>
#     <tr>
#       <th id="T_8cbcc_level0_row2" class="row_heading level0 row2" >mlp_custom3_preds</th>
#       <td id="T_8cbcc_row2_col0" class="data row2 col0" >98.5%</td>
#       <td id="T_8cbcc_row2_col1" class="data row2 col1" >93.5%</td>
#       <td id="T_8cbcc_row2_col2" class="data row2 col2" >86.0%</td>
#     </tr>
#     <tr>
#       <th id="T_8cbcc_level0_row3" class="row_heading level0 row3" >mlp_sklearn_preds</th>
#       <td id="T_8cbcc_row3_col0" class="data row3 col0" >97.1%</td>
#       <td id="T_8cbcc_row3_col1" class="data row3 col1" >93.0%</td>
#       <td id="T_8cbcc_row3_col2" class="data row3 col2" >84.5%</td>
#     </tr>
#   </tbody>
# </table>

# %%
metr_split = metrics_split(
    data=data.loc[DEV_MASK],
    target=TARGET,
    pred_cols=['mlp_sklearn_preds', 'mlp_custom1_preds',
               'mlp_custom2_preds', 'mlp_custom3_preds'],
    group_cols=DATE_MONTH,
    metr_calc=rocauc_metr_calc,
    asc=False
)


(metr_split
    .pivot_table(index='level_1',
                 columns=metr_split.index,
                 values='roc_auc')
    .style
    .format("{:.1%}")
    .background_gradient(cmap='RdYlGn', axis=None)
 )
# Out:
# <style type="text/css">
# #T_a5d70_row0_col0 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_a5d70_row0_col1 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_a5d70_row0_col2 {
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_a5d70_row0_col3 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_a5d70_row0_col4 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_a5d70_row0_col5 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_a5d70_row0_col6 {
#   background-color: #c82227;
#   color: #f1f1f1;
# }
# #T_a5d70_row1_col0 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_a5d70_row1_col1 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_a5d70_row1_col2 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_a5d70_row1_col3 {
#   background-color: #39a758;
#   color: #f1f1f1;
# }
# #T_a5d70_row1_col4 {
#   background-color: #30a356;
#   color: #f1f1f1;
# }
# #T_a5d70_row1_col5 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_a5d70_row1_col6 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_a5d70_row2_col0 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_a5d70_row2_col1 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_a5d70_row2_col2 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_a5d70_row2_col3 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_a5d70_row2_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_a5d70_row2_col5 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_a5d70_row2_col6 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_a5d70_row3_col0 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_a5d70_row3_col1 {
#   background-color: #18954f;
#   color: #f1f1f1;
# }
# #T_a5d70_row3_col2 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_a5d70_row3_col3 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_a5d70_row3_col4 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_a5d70_row3_col5 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_a5d70_row3_col6 {
#   background-color: #fa9857;
#   color: #000000;
# }
# </style>
# <table id="T_a5d70">
#   <thead>
#     <tr>
#       <th class="index_name level0" >date_month</th>
#       <th id="T_a5d70_level0_col0" class="col_heading level0 col0" >2020-01</th>
#       <th id="T_a5d70_level0_col1" class="col_heading level0 col1" >2020-02</th>
#       <th id="T_a5d70_level0_col2" class="col_heading level0 col2" >2020-03</th>
#       <th id="T_a5d70_level0_col3" class="col_heading level0 col3" >2020-04</th>
#       <th id="T_a5d70_level0_col4" class="col_heading level0 col4" >2020-05</th>
#       <th id="T_a5d70_level0_col5" class="col_heading level0 col5" >2020-06</th>
#       <th id="T_a5d70_level0_col6" class="col_heading level0 col6" >2020-07</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >level_1</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5d70_level0_row0" class="row_heading level0 row0" >mlp_custom1_preds</th>
#       <td id="T_a5d70_row0_col0" class="data row0 col0" >87.1%</td>
#       <td id="T_a5d70_row0_col1" class="data row0 col1" >89.9%</td>
#       <td id="T_a5d70_row0_col2" class="data row0 col2" >90.8%</td>
#       <td id="T_a5d70_row0_col3" class="data row0 col3" >89.8%</td>
#       <td id="T_a5d70_row0_col4" class="data row0 col4" >89.0%</td>
#       <td id="T_a5d70_row0_col5" class="data row0 col5" >79.6%</td>
#       <td id="T_a5d70_row0_col6" class="data row0 col6" >80.9%</td>
#     </tr>
#     <tr>
#       <th id="T_a5d70_level0_row1" class="row_heading level0 row1" >mlp_custom2_preds</th>
#       <td id="T_a5d70_row1_col0" class="data row1 col0" >93.7%</td>
#       <td id="T_a5d70_row1_col1" class="data row1 col1" >95.1%</td>
#       <td id="T_a5d70_row1_col2" class="data row1 col2" >95.6%</td>
#       <td id="T_a5d70_row1_col3" class="data row1 col3" >95.0%</td>
#       <td id="T_a5d70_row1_col4" class="data row1 col4" >95.2%</td>
#       <td id="T_a5d70_row1_col5" class="data row1 col5" >87.5%</td>
#       <td id="T_a5d70_row1_col6" class="data row1 col6" >87.3%</td>
#     </tr>
#     <tr>
#       <th id="T_a5d70_level0_row2" class="row_heading level0 row2" >mlp_custom3_preds</th>
#       <td id="T_a5d70_row2_col0" class="data row2 col0" >96.1%</td>
#       <td id="T_a5d70_row2_col1" class="data row2 col1" >96.9%</td>
#       <td id="T_a5d70_row2_col2" class="data row2 col2" >97.4%</td>
#       <td id="T_a5d70_row2_col3" class="data row2 col3" >97.2%</td>
#       <td id="T_a5d70_row2_col4" class="data row2 col4" >97.6%</td>
#       <td id="T_a5d70_row2_col5" class="data row2 col5" >86.0%</td>
#       <td id="T_a5d70_row2_col6" class="data row2 col6" >85.8%</td>
#     </tr>
#     <tr>
#       <th id="T_a5d70_level0_row3" class="row_heading level0 row3" >mlp_sklearn_preds</th>
#       <td id="T_a5d70_row3_col0" class="data row3 col0" >94.5%</td>
#       <td id="T_a5d70_row3_col1" class="data row3 col1" >95.9%</td>
#       <td id="T_a5d70_row3_col2" class="data row3 col2" >96.6%</td>
#       <td id="T_a5d70_row3_col3" class="data row3 col3" >96.0%</td>
#       <td id="T_a5d70_row3_col4" class="data row3 col4" >96.3%</td>
#       <td id="T_a5d70_row3_col5" class="data row3 col5" >84.5%</td>
#       <td id="T_a5d70_row3_col6" class="data row3 col6" >84.4%</td>
#     </tr>
#   </tbody>
# </table>
